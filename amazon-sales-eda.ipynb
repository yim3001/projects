# %% [markdown]
# # <B>Amazon Sales Dataset</B>
# - Week10

# %% [markdown]
# ## 1. Data Collection

# %%
import pandas as pd 

import numpy as np
import seaborn as sns

# %% [markdown]
# ### Load dataset

# %%
data = pd.read_csv('amazon.csv')
data.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %% [markdown]
# ### Data columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
data.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
data['product_name']
# Out:
# 0       Wayona Nylon Braided USB to Lightning Fast Cha...
# 1       Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2       Sounce Fast Phone Charging Cable & Data Sync U...
# 3       boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4       Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#                               ...
# 1460    Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461    Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462    Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463    Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464    Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
# Name: product_name, Length: 1465, dtype: object

# %%
for x in data.columns: 
    print(x)
    print(data[x].values)
# Out:
# product_id
# ['B07JW9H4J1' 'B098NS6PVG' 'B096MSW6CT' ... 'B009P2LIL4' 'B00J5DYCCA'
#  'B01486F4G6']
# product_name
# ['Wayona Nylon Braided USB to Lightning Fast Charging and Data Sync Cable Compatible for iPhone 13, 12,11, X, 8, 7, 6, 5, iPad Air, Pro, Mini (3 FT Pack of 1, Grey)'
#  'Ambrane Unbreakable 60W / 3A Fast Charging 1.5m Braided Type C Cable for Smartphones, Tablets, Laptops & other Type C devices, PD Technology, 480Mbps Data Sync, Quick Charge 3.0 (RCT15A, Black)'
#  'Sounce Fast Phone Charging Cable & Data Sync USB Cable Compatible for iPhone 13, 12,11, X, 8, 7, 6, 5, iPad Air, Pro, Mini & iOS Devices'
#  ...
#  'Bajaj Majesty RX10 2000 Watts Heat Convector Room Heater (White, ISI Approved)'
#  'Havells Ventil Air DSP 230mm Exhaust Fan (Pista Green)'
#  'Borosil Jumbo 1000-Watt Grill Sandwich Maker (Black)']
# category
# ['Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables'
# ...

# %% [markdown]
# ## 2. Data Preparation

# %%
df = data.copy()

# %% [markdown]
# ### Check for missing values

# %%
def check_missing_values(dataframe):
    return dataframe.isnull().sum()

print(check_missing_values(df))
df[df.rating_count.isnull()]
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64
#      product_id                                       product_name  \
# 282  B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#                                               category discounted_price  \
# 282  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 324  Computers&Accessories|Accessories&Peripherals|...             ₹249
#
#     actual_price discount_percentage rating rating_count  \
# ...

# %%
# Remove rows with missing values in the rating_count column
df.dropna(subset=['rating_count'], inplace=True)
print(check_missing_values(df))
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %% [markdown]
# ### Check for duplicates

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ### Check data types

# %%
df.dtypes
# Out:
# product_id             object
# product_name           object
# category               object
# discounted_price       object
# actual_price           object
# discount_percentage    object
# rating                 object
# rating_count           object
# about_product          object
# user_id                object
# user_name              object
# review_id              object
# review_title           object
# review_content         object
# img_link               object
# product_link           object
# dtype: object

# %% [markdown]
# ### Change data types

# %% [markdown]
# #### discounted_price, actual_price, discount_percentage

# %%
print(data['discounted_price'].values)
print(data['actual_price'].values)
print(data['discount_percentage'].values)
# Out:
# ['₹399' '₹199' '₹199' ... '₹2,219' '₹1,399' '₹2,863']
# ['₹1,099' '₹349' '₹1,899' ... '₹3,080' '₹1,890' '₹3,690']
# ['64%' '43%' '90%' ... '28%' '26%' '22%']

# %%
# Currency,  replace
df['discounted_price'] = df['discounted_price'].str.replace('₹', '').str.replace(',', '').astype(float)
df['actual_price'] = df['actual_price'].str.replace('₹', '').str.replace(',', '').astype(float)
df['discount_percentage'] = df['discount_percentage'].str.replace('%','').astype(float)/100

# %%
df.dtypes
# Out:
# product_id              object
# product_name            object
# category                object
# discounted_price       float64
# actual_price           float64
# discount_percentage    float64
# rating                  object
# rating_count            object
# about_product           object
# user_id                 object
# user_name               object
# review_id               object
# review_title            object
# review_content          object
# img_link                object
# product_link            object
# dtype: object

# %% [markdown]
# #### Rating

# %%
df['rating'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[266], line 1
# ----> 1 df['rating'].astype(float)
#
# File c:\Users\eunseok\anaconda3\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File c:\Users\eunseok\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
# '|' 행 삭제하는 방법

df[df['rating'].isin(['|'])]['rating']
# df = df[~df['rating'].isin(['|'])]
# df = df[df['rating']!='|']
# Out:
# 1279    |
# Name: rating, dtype: object

# %%
df = df[df['rating'].apply(lambda x: '|' not in x)]

# %%
#Check '|' count 
print(df['rating'].str.contains('\|').sum())
# Out:
# 0

# %%
df['rating'] = df['rating'].astype('float')
df['rating'].head()
# Out:
# 0    4.2
# 1    4.0
# 2    3.9
# 3    4.2
# 4    4.2
# Name: rating, dtype: float64

# %% [markdown]
# ### rating_count

# %%
df['rating_count'].head()
# Out:
# 0    24,269
# 1    43,994
# 2     7,928
# 3    94,363
# 4    16,905
# Name: rating_count, dtype: object

# %%
df['rating_count'] = df['rating_count'].str.replace(',', '').astype(float)
df['rating_count']
# Out:
# 0       24269.0
# 1       43994.0
# 2        7928.0
# 3       94363.0
# 4       16905.0
#          ...
# 1460     1090.0
# 1461     4118.0
# 1462      468.0
# 1463     8031.0
# 1464     6987.0
# Name: rating_count, Length: 1462, dtype: float64

# %%
df[df['rating_count'] % 1 != 0]['rating_count'] # rating_count는 소수가 아니어서 int로 바꿔줘도 됨
# Out:
# Series([], Name: rating_count, dtype: float64)

# %%
df.dtypes
# Out:
# product_id              object
# product_name            object
# category                object
# discounted_price       float64
# actual_price           float64
# discount_percentage    float64
# rating                 float64
# rating_count           float64
# about_product           object
# user_id                 object
# user_name               object
# review_id               object
# review_title            object
# review_content          object
# img_link                object
# product_link            object
# dtype: object

# %% [markdown]
# #### Category
# - Split and create new column

# %%
df['category'].values
# Out:
# array(['Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables',
#        'Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables',
#        'Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables',
#        ...,
#        'Home&Kitchen|Heating,Cooling&AirQuality|RoomHeaters|HeatConvectors',
#        'Home&Kitchen|Heating,Cooling&AirQuality|Fans|ExhaustFans',
#        'Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|SandwichMakers'],
#       dtype=object)

# %%
df['main_category'] = df['category'].str.split('|').str[0] # 그냥 [0]하면 첫번째 행 가져오지만 str[0]하면 첫번째 원소들을 행마다 가져옴.
df['sub_category'] = df['category'].str.split('|').str[-1]

# %%
print(df['main_category'].values)
print(df['sub_category'].values)
# Out:
# ['Computers&Accessories' 'Computers&Accessories' 'Computers&Accessories'
#  ... 'Home&Kitchen' 'Home&Kitchen' 'Home&Kitchen']
# ['USBCables' 'USBCables' 'USBCables' ... 'HeatConvectors' 'ExhaustFans'
#  'SandwichMakers']

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link', 'main_category',
#        'sub_category'],
#       dtype='object')

# %%
df.shape
# Out:
# (1462, 18)

# %%
df.head(1)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                 0.64     4.2       24269.0
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
#
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
#
# ...

# %%
df.describe()
# Out:
#        discounted_price   actual_price  discount_percentage       rating  \
# count       1462.000000    1462.000000          1462.000000  1462.000000
# mean        3129.981826    5453.087743             0.476724     4.096717
# std         6950.548042   10884.467444             0.216139     0.289497
# min           39.000000      39.000000             0.000000     2.000000
# 25%          325.000000     800.000000             0.320000     4.000000
# 50%          799.000000    1670.000000             0.500000     4.100000
# 75%         1999.000000    4321.250000             0.630000     4.300000
# max        77990.000000  139900.000000             0.940000     5.000000
#
#         rating_count
# count    1462.000000
# mean    18307.376881
# std     42766.096572
# min         2.000000
# 25%      1191.500000
# 50%      5179.000000
# 75%     17342.250000
# max    426973.000000

# %% [markdown]
# ## <b>3. EDA</b>

# %% [markdown]
# ### <B>Top10 Main Category & Sub Category</B>

# %%
df['main_category'].value_counts()
# Out:
# Electronics              526
# Computers&Accessories    451
# Home&Kitchen             447
# OfficeProducts            31
# MusicalInstruments         2
# HomeImprovement            2
# Toys&Games                 1
# Car&Motorbike              1
# Health&PersonalCare        1
# Name: main_category, dtype: int64

# %%
df['sub_category'].value_counts()
# Out:
# USBCables             231
# SmartWatches           76
# Smartphones            68
# SmartTelevisions       63
# In-Ear                 52
#                      ...
# InternalHardDrives      1
# WoodenPencils           1
# BatteryChargers         1
# DataCards&Dongles       1
# HandheldBags            1
# Name: sub_category, Length: 207, dtype: int64

# %%
import matplotlib.pyplot as plt # matplotlib은 ax를 매개변수로 직접 전달하지 않음.

main_category_counts = df['main_category'].value_counts() # main_category는 9개밖에 없음.
sub_category_counts = df['sub_category'].value_counts()[:10]
fig, ax = plt.subplots(1, 2, figsize=(15,5))

ax[0].bar(main_category_counts.index, main_category_counts.values) # 처음부터 x를 index로, y를 values로 함
ax[0].set_ylabel('Number of Products')
ax[0].set_title('Distribution of Products by Main Category (Top 9)')
ax[0].tick_params(axis='x', rotation=90, labelsize=8)

ax[1].bar(sub_category_counts.index, sub_category_counts.values)
ax[1].set_ylabel('Number of Products')
ax[1].set_title('Distribution of Products by Sub-Category (Top 10)')
ax[1].tick_params(axis='x', rotation=90, labelsize=8)
plt.show()

# %% [markdown]
# ### <u><b>Rating</u></b>

# %% [markdown]
# #### Distribution of Rating
# - 리뷰 평점에 대한 분포도를 확인

# %%
df['rating']
# Out:
# 0       4.2
# 1       4.0
# 2       3.9
# 3       4.2
# 4       4.2
#        ...
# 1460    4.0
# 1461    4.1
# 1462    3.6
# 1463    4.0
# 1464    4.3
# Name: rating, Length: 1462, dtype: float64

# %%
plt.hist(df['rating'])
plt.xlabel('Rating')
plt.ylabel('Number of Reviews')
plt.title('Distribution of Customer Ratings')
plt.show()

# %% [markdown]
# #### Rating - Cluster
# - 리뷰 평점을 5개의 Cluster로 나누어, 리뷰갯수의 분포를 확인

# %%
for i in range(5):
    count = len(df[(i < df['rating']) & (df['rating'] <= i+1)])
    print(f'{i}-{i+1} {count}')
# Out:
# 0-1 0
# 1-2 1
# 2-3 8
# 3-4 525
# 4-5 928

# %%
# Create table with values per cluster
bins = [0, 1, 2, 3, 4, 5] # Define bin edges
df['cluster'] = pd.cut(df['rating'], bins=bins, include_lowest=True, labels=['0-1', '1-2', '2-3', '3-4', '4-5']) # include_lowest=True는 첫번째 구간인 0-1에서만 0을 포함시킴.

print(df['cluster'].value_counts())
# Out:
# 4-5    928
# 3-4    525
# 2-3      8
# 1-2      1
# 0-1      0
# Name: cluster, dtype: int64

# %%
df['cluster'].value_counts().reset_index().sort_values('cluster')
# Out:
#   index  cluster
# 4   0-1        0
# 3   1-2        1
# 2   2-3        8
# 1   3-4      525
# 0   4-5      928

# %%
df_review_cluster_cnt = df['cluster'].value_counts().reset_index().sort_values('cluster').rename(columns={'index':'Cluster', 'cluster':'Number of Reviews'})

df_review_cluster_cnt
# Out:
#   Cluster  Number of Reviews
# 4     0-1                  0
# 3     1-2                  1
# 2     2-3                  8
# 1     3-4                525
# 0     4-5                928

# %%
# index로 정렬하는 것도 가능
table = df['cluster'].value_counts().reset_index().sort_values('index').rename(columns={'index':'Cluster', 'cluster':'Number of Reviews'})
table
# Out:
#   Cluster  Number of Reviews
# 4     0-1                  0
# 3     1-2                  1
# 2     2-3                  8
# 1     3-4                525
# 0     4-5                928

# %% [markdown]
# #### Max Rating - sub_category

# %%
max_rating_per_subcategory = df.groupby('sub_category')['rating'].max().reset_index().rename(columns={'rating':'max_rating'})

max_rating_per_subcategory = max_rating_per_subcategory.sort_values(by = 'max_rating', ascending=False).reset_index(drop=True)
max_rating_per_subcategory
# Out:
#             sub_category  max_rating
# 0              USBCables         5.0
# 1                   Mice         5.0
# 2           HandBlenders         4.8
# 3    InstantWaterHeaters         4.8
# 4              AirFryers         4.8
# ..                   ...         ...
# 202         VideoCameras         3.7
# 203           PCHeadsets         3.5
# 204           DustCovers         3.5
# 205            3DGlasses         3.5
# 206     ElectricGrinders         3.3
#
# [207 rows x 2 columns]

# %% [markdown]
# #### Min Rating

# %%
min_rating_per_subcategory = df.groupby('sub_category')['rating'].min().reset_index()
min_rating_per_subcategory.columns = ['sub_category', 'min_rating']

#Sort values 
min_rating_per_subcategory = min_rating_per_subcategory.sort_values(by='min_rating', ascending=True).reset_index(drop=True)
min_rating_per_subcategory
# Out:
#                         sub_category  min_rating
# 0                         FanHeaters         2.0
# 1                       HandBlenders         2.3
# 2                      VacuumSealers         2.6
# 3                JuicerMixerGrinders         2.8
# 4                       SmartWatches         2.8
# ..                               ...         ...
# 202                 PowerLANAdapters         4.5
# 203                PaintingMaterials         4.5
# 204  SmallApplianceParts&Accessories         4.5
# 205                  SurgeProtectors         4.5
# 206                          Tablets         4.6
#
# [207 rows x 2 columns]

# %% [markdown]
# #### <B>Top Main & Sub Category by Rating</B>

# %%
top_main_rating = df.groupby('main_category')['rating'].mean().sort_values(ascending=False).reset_index().rename(columns={'rating':'mean_rating'})
top_sub_rating = df.groupby(['sub_category'])['rating'].mean().sort_values(ascending=False).head(10).reset_index().rename(columns={'rating':'mean_rating'})

figure, ax = plt.subplots(1,2, figsize=(12,5))
ax[0].bar(top_main_rating['main_category'], top_main_rating['mean_rating'])
ax[0].set_xlabel('main_category')
ax[0].set_ylabel('Rating')
ax[0].set_title('Top 9 main_category by Rating')
ax[0].tick_params(rotation=90)

ax[1].bar(top_sub_rating['sub_category'], top_sub_rating['mean_rating'])
ax[1].set_xlabel('sub_category')
ax[1].set_ylabel('Rating')
ax[1].set_title('Top 10 sub_category by Rating')
ax[1].tick_params(rotation=90)

plt.show()

ranking_rating_sub_cat = df.groupby(['sub_category','main_category'])['rating'].mean().sort_values(ascending=False).reset_index()
ranking_rating_sub_cat
# Out:
#          sub_category          main_category  rating
# 0             Tablets  Computers&Accessories     4.6
# 1              Memory  Computers&Accessories     4.5
# 2               Basic         OfficeProducts     4.5
# 3     SurgeProtectors            Electronics     4.5
# 4      CordManagement        HomeImprovement     4.5
# ..                ...                    ...     ...
# 205    InkjetPrinters  Computers&Accessories     3.6
# 206        PCHeadsets  Computers&Accessories     3.5
# 207         3DGlasses            Electronics     3.5
# 208        DustCovers  Computers&Accessories     3.4
# 209  ElectricGrinders           Home&Kitchen     3.3
#
# [210 rows x 3 columns]

# %% [markdown]
# #### <B>Bottom Main Category by Rating</B>

# %%
bottom_main_rating = df.groupby(['main_category'])['rating'].mean().sort_values(ascending=True).reset_index()

# Create a bar plot
plt.bar(bottom_main_rating['main_category'], bottom_main_rating['rating'])

plt.xlabel('main_category')
plt.ylabel('Rating')
plt.title('Bottom 9 main_category by Rating')

plt.xticks(rotation=90)
plt.show()

bottom_main_rating
# Out:
#            main_category    rating
# 0          Car&Motorbike  3.800000
# 1     MusicalInstruments  3.900000
# 2    Health&PersonalCare  4.000000
# 3           Home&Kitchen  4.040716
# 4            Electronics  4.081749
# 5  Computers&Accessories  4.155654
# 6        HomeImprovement  4.250000
# 7             Toys&Games  4.300000
# 8         OfficeProducts  4.309677

# %% [markdown]
# #### <B>Bottom 10 Sub Category by Rating</B>

# %%
# Calculate the top sub categories
bottom_sub_rating = df.groupby(['sub_category'])['rating'].mean().sort_values(ascending=False).tail(10).reset_index()

# Create a bar plot
plt.bar(bottom_sub_rating['sub_category'], bottom_sub_rating['rating'])

# Add labels and title
plt.xlabel('sub_category')
plt.ylabel('Rating')
plt.title('Top 10 sub_category by Rating')

# Rotate x-axis labels
plt.xticks(rotation=90)

# Show the plot
plt.show()

bottom_sub_rating
# Out:
#                 sub_category    rating
# 0              VacuumSealers  3.671429
# 1                   Printers  3.666667
# 2  Sewing&EmbroideryMachines  3.650000
# 3             HalogenHeaters  3.600000
# 4              PCMicrophones  3.600000
# 5             InkjetPrinters  3.600000
# 6                 PCHeadsets  3.500000
# 7                  3DGlasses  3.500000
# 8                 DustCovers  3.400000
# 9           ElectricGrinders  3.300000

# %% [markdown]
# ### <B><u>Rating Count</B></u>
# - Number of people who voted for the Amazon rating; 아마존 제품 평가에 투표한 사람 수

# %%
df['rating_count'].describe()
# Out:
# count      1462.000000
# mean      18307.376881
# std       42766.096572
# min           2.000000
# 25%        1191.500000
# 50%        5179.000000
# 75%       17342.250000
# max      426973.000000
# Name: rating_count, dtype: float64

# %% [markdown]
# #### <b>Top Main Category by Rating Count </b>

# %%
top_main_rating_cnt = df.groupby(['main_category'])['rating_count'].sum().sort_values(ascending=False).reset_index()

plt.bar(top_main_rating_cnt['main_category'], top_main_rating_cnt['rating_count'])
plt.xlabel('Main Category')
plt.ylabel('Rating Count')
plt.title('Top Main Categories by Rating Count')
plt.xticks(rotation=90)
plt.show()

top_main_rating_cnt
# Out:
#            main_category  rating_count
# 0            Electronics    15778848.0
# 1  Computers&Accessories     7728689.0
# 2           Home&Kitchen     2990077.0
# 3         OfficeProducts      149675.0
# 4     MusicalInstruments       88882.0
# 5             Toys&Games       15867.0
# 6        HomeImprovement        8566.0
# 7    Health&PersonalCare        3663.0
# 8          Car&Motorbike        1118.0

# %% [markdown]
# #### <b>Top 10 Sub Category by Rating Count </b>

# %%
top_sub_rating_cnt = df.groupby(['sub_category'])['rating_count'].sum().sort_values(ascending=False).head(10).reset_index()

plt.bar(top_sub_rating_cnt['sub_category'], top_sub_rating_cnt['rating_count'])
plt.xlabel('Sub Category')
plt.ylabel('Rating Count')
plt.title('Top 10 Sub Categories by Rating Count')
plt.xticks(rotation=90)
plt.show()

# Full ranking of main categories by rating count
ranking_rating_sub_cat = df.groupby('sub_category')['rating_count'].sum().sort_values(ascending=False).reset_index()
ranking_rating_sub_cat
# Out:
#            sub_category  rating_count
# 0                In-Ear     4204939.0
# 1             USBCables     3547816.0
# 2           Smartphones     2493269.0
# 3            HDMICables     1906054.0
# 4          SmartWatches     1644476.0
# ..                  ...           ...
# 202  InternalHardDrives         362.0
# 203  TraditionalLaptops         323.0
# 204         PhoneCharms         305.0
# 205       TowerSpeakers         282.0
# 206    StreamingClients         224.0
#
# [207 rows x 2 columns]

# %% [markdown]
# #### <b>카테고리별로 평점 수(rating_count)가 가장 많은 제품 찾기</b>

# %%
top_products = df.loc[df.groupby('main_category')['rating_count'].idxmax(), ['main_category', 'sub_category', 'product_name', 'rating_count']]
top_products = top_products.reset_index(drop=True)

top_products
# Out:
#            main_category           sub_category  \
# 0          Car&Motorbike  AirPurifiers&Ionizers
# 1  Computers&Accessories              PenDrives
# 2            Electronics             HDMICables
# 3    Health&PersonalCare  DigitalBathroomScales
# 4           Home&Kitchen               Choppers
# 5        HomeImprovement         CordManagement
# 6     MusicalInstruments              Condenser
# 7         OfficeProducts             Scientific
# 8             Toys&Games  ColouringPens&Markers
#
#                                         product_name  rating_count
# 0  Reffair AX30 [MAX] Portable Air Purifier for C...        1118.0
# 1          SanDisk Cruzer Blade 32GB USB Flash Drive      253105.0
# 2  AmazonBasics Flexible Premium HDMI Cable (Blac...      426973.0
# 3  Dr Trust Electronic Kitchen Digital Scale Weig...        3663.0
# 4  Pigeon Polypropylene Mini Handy and Compact Ch...      270563.0
# 5  Gizga Essentials Cable Organiser, Cord Managem...        5985.0
# ...

# %% [markdown]
# ### <b><u>Price</b></u>

# %% [markdown]
# #### Discounted prices vs. Actual Prices

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link', 'main_category',
#        'sub_category', 'cluster'],
#       dtype='object')

# %% [markdown]
# #### Distribution with histogram

# %%
# Plotting the distribution of discounted prices vs. actual prices
plt.figure(figsize=(10, 6))
plt.hist(df['discounted_price'], bins=30, alpha=0.5, label='Discounted Price') # alpha: 투명도
plt.hist(df['actual_price'], bins=30, alpha=0.5, label='Actual Price')

plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Distribution of Discounted Prices vs. Actual Prices')
plt.legend()

plt.show()

# %% [markdown]
# #### Distribution with Density Plot

# %%
plt.figure(figsize=(8, 5))
sns.kdeplot(df['discounted_price'], label='Discounted Price', fill=True, alpha=0.5)
sns.kdeplot(df['actual_price'], label='Actual Price', fill=True, alpha=0.5)
plt.xlabel('Price')
plt.ylabel('Density')
plt.title('Density Plot of Discounted Prices vs. Actual Prices')
plt.legend() 
plt.show()

# %% [markdown]
# ### <b>Average Discount Percentage</b>

# %% [markdown]
# #### By Main_Category

# %%
df.groupby('main_category')['discount_percentage'].mean()
# Out:
# main_category
# Car&Motorbike            0.420000
# Computers&Accessories    0.539202
# Electronics              0.508289
# Health&PersonalCare      0.530000
# Home&Kitchen             0.401745
# HomeImprovement          0.575000
# MusicalInstruments       0.460000
# OfficeProducts           0.123548
# Toys&Games               0.000000
# Name: discount_percentage, dtype: float64

# %%
avg_discount_by_category = df.groupby('main_category')['discount_percentage'].mean().sort_values(ascending=False).reset_index()

# Plotting the average discount percentage by category
plt.figure(figsize=(10, 5))
plt.bar(avg_discount_by_category['main_category'], avg_discount_by_category['discount_percentage'])
plt.xlabel('Category')
plt.ylabel('Average Discount Percentage')
plt.title('Average Discount Percentage by main_category')
plt.xticks(rotation=90)
plt.show()

avg_discount_by_category
# Out:
#            main_category  discount_percentage
# 0        HomeImprovement             0.575000
# 1  Computers&Accessories             0.539202
# 2    Health&PersonalCare             0.530000
# 3            Electronics             0.508289
# 4     MusicalInstruments             0.460000
# 5          Car&Motorbike             0.420000
# 6           Home&Kitchen             0.401745
# 7         OfficeProducts             0.123548
# 8             Toys&Games             0.000000

# %% [markdown]
# #### By Sub-category

# %%
df.groupby('sub_category')['discount_percentage'].mean()
# Out:
# sub_category
# 3DGlasses                 0.230000
# AVReceivers&Amplifiers    0.360000
# Adapters                  0.803333
# Adapters&Multi-Outlets    0.570000
# AirFryers                 0.440000
#                             ...
# WetGrinders               0.215000
# WireboundNotebooks        0.057500
# WirelessUSBAdapters       0.491111
# WoodenPencils             0.000000
# YogurtMakers              0.550000
# Name: discount_percentage, Length: 207, dtype: float64

# %%
avg_discount_by_subcategory = df.groupby('sub_category')['discount_percentage'].mean().sort_values(ascending=False).reset_index().head(10)

# Plotting the average discount percentage by category
plt.figure(figsize=(10, 6))
plt.bar(avg_discount_by_subcategory['sub_category'], avg_discount_by_subcategory['discount_percentage'])
plt.xlabel('Category')
plt.ylabel('Average Discount Percentage')
plt.title('Top 10 Average Discount Percentage by sub_category')
plt.xticks(rotation=90)
plt.show()

avg_discount_by_subcategory
# Out:
#                 sub_category  discount_percentage
# 0                PhoneCharms             0.900000
# 1                    Earpads             0.900000
# 2  CableConnectionProtectors             0.900000
# 3                 DustCovers             0.875000
# 4          Shower&WallMounts             0.820000
# 5                   Adapters             0.803333
# 6         InternalHardDrives             0.800000
# 7           USBtoUSBAdapters             0.785000
# 8                     Stands             0.758182
# 9     NotebookComputerStands             0.756667

# %%
df.groupby('sub_category')['discount_percentage'].mean().sort_values(ascending=False).reset_index().tail(10)
# Out:
#               sub_category  discount_percentage
# 197     Financial&Business                  0.0
# 198          WoodenPencils                  0.0
# 199  StandMixerAccessories                  0.0
# 200      PaintingMaterials                  0.0
# 201   GelInkRollerballPens                  0.0
# 202                  Basic                  0.0
# 203  ColouringPens&Markers                  0.0
# 204                   Film                  0.0
# 205       StreamingClients                  0.0
# 206          ColouredPaper                  0.0

# %% [markdown]
# ### <b><u>Product Name</b></u>

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link', 'main_category',
#        'sub_category', 'cluster'],
#       dtype='object')

# %% [markdown]
# ####  Top 10 most popular products based on Average rating

# %%
# the most popular product names based on rating 
top10_products_rating = df.groupby('product_name')['rating'].mean().sort_values(ascending=False).head(10).reset_index()

top10_products_rating
# Out:
#                                         product_name  rating
# 0  Amazon Basics Wireless Mouse | 2.4 GHz Connect...     5.0
# 1  Syncwire LTG to USB Cable for Fast Charging Co...     5.0
# 2  Oratech Coffee Frother electric, milk frother ...     4.8
# 3  Swiffer Instant Electric Water Heater Faucet T...     4.8
# 4  Instant Pot Air Fryer, Vortex 2QT, Touch Contr...     4.8
# 5  Zuvexa USB Rechargeable Electric Foam Maker - ...     4.7
# 6  Spigen EZ Fit Tempered Glass Screen Protector ...     4.7
# 7  FIGMENT Handheld Milk Frother Rechargeable, 3-...     4.7
# 8  Campfire Spring Chef Prolix Instant Portable W...     4.7
# 9  Multifunctional 2 in 1 Electric Egg Boiling St...     4.7

# %% [markdown]
# ####  Top 10 most popular products based on rating count

# %%
# the most popular product names based on rating count
top10_products_rating_cnt = df.groupby('product_name')['rating_count'].sum().sort_values(ascending=False).head(10).reset_index()

top10_products_rating_cnt
# Out:
#                                         product_name  rating_count
# 0  AmazonBasics Flexible Premium HDMI Cable (Blac...      853945.0
# 1  Amazon Basics High-Speed HDMI Cable, 6 Feet - ...      426973.0
# 2  Amazon Basics High-Speed HDMI Cable, 6 Feet (2...      426973.0
# 3  JBL C100SI Wired In Ear Headphones with Mic, J...      385177.0
# 4  boAt Bassheads 100 in Ear Wired Earphones with...      363713.0
# 5  boAt Bassheads 100 in Ear Wired Earphones with...      363713.0
# 6  boAt BassHeads 100 in-Ear Wired Headphones wit...      363711.0
# 7  Redmi 9 Activ (Carbon Black, 4GB RAM, 64GB Sto...      313836.0
# 8  Redmi 9A Sport (Coral Green, 2GB RAM, 32GB Sto...      313836.0
# 9  Redmi 9A Sport (Carbon Black, 2GB RAM, 32GB St...      313832.0

# %%
top10_products_rating['product_name'].to_list() # 별점 높은 상품 10개
# Out:
# ['Amazon Basics Wireless Mouse | 2.4 GHz Connection, 1600 DPI | Type - C Adapter | Upto 12 Months of Battery Life | Ambidextrous Design | Suitable for PC/Mac/Laptop',
#  'Syncwire LTG to USB Cable for Fast Charging Compatible with Phone 5/ 5C/ 5S/ 6/ 6S/ 7/8/ X/XR/XS Max/ 11/12/ 13 Series and Pad Air/Mini, Pod & Other Devices (1.1 Meter, White)',
#  'Oratech Coffee Frother electric, milk frother electric, coffee beater, cappuccino maker, Coffee Foamer, Mocktail Mixer, Coffee Foam Maker, coffee whisker electric, Froth Maker, coffee stirrers electric, coffee frothers, Coffee Blender, (6 Month Warranty) (Multicolour)',
#  'Swiffer Instant Electric Water Heater Faucet Tap Home-Kitchen Instantaneous Water Heater Tank less for Tap, LED Electric Head Water Heaters Tail Gallon Comfort(3000W) ((Pack of 1))',
#  'Instant Pot Air Fryer, Vortex 2QT, Touch Control Panel, 360° EvenCrisp™ Technology, Uses 95 % less Oil, 4-in-1 Appliance: Air Fry, Roast, Bake, Reheat (Vortex 1.97Litre, Black)',
# ...

# %% [markdown]
# #### <b><u>Popular product 찾기</b></u> - rating count도 많고, rating도 높은 product 찾기

# %%
top1_rating = top10_products_rating['product_name'][0]

df[df['product_name']==top1_rating][['product_name', 'rating', 'rating_count']] # rating이 높지만 rating_count가 낮음
# Out:
#                                           product_name  rating  rating_count
# 775  Amazon Basics Wireless Mouse | 2.4 GHz Connect...     5.0          23.0

# %%
top1_rating_cnt = top10_products_rating_cnt['product_name'][0]

df[df['product_name']==top1_rating_cnt][['product_name', 'rating', 'rating_count']] # rating이 top 100에 속하지 못했지만 좋고, rating_count가 매우 높음
# Out:
#                                           product_name  rating  rating_count
# 12   AmazonBasics Flexible Premium HDMI Cable (Blac...     4.4      426973.0
# 684  AmazonBasics Flexible Premium HDMI Cable (Blac...     4.4      426972.0

# %%
rating_products = df.groupby('product_name')['rating'].mean().sort_values(ascending=False).head(100).reset_index()
rating_cnt_products = df.groupby('product_name')['rating_count'].sum().sort_values(ascending=False).head(100).reset_index()

rating_products_name = rating_products['product_name'].to_list()
rating_cnt_products_name = rating_cnt_products['product_name'].to_list()

filtered_rows = []

for i in rating_cnt_products_name:
    if i in rating_products_name:
        row = df[df['product_name'] == i][['product_name', 'rating_count', 'rating']]
        filtered_rows.append(row) # list에 데이터프레임 하나씩 넣기

famous_product = pd.concat(filtered_rows, ignore_index=True) # concat: 수직으로 병합

famous_product # rating_count top 100 중에 rating도 top 100인 product
# Out:
#                                         product_name  rating_count  rating
# 0  AmazonBasics USB 2.0 Cable - A-Male to B-Male ...      107687.0     4.5
# 1  AmazonBasics USB 2.0 Cable - A-Male to B-Male ...      107686.0     4.5
# 2  SanDisk Extreme SD UHS I 64GB Card for 4K Vide...      205052.0     4.5
# 3  AmazonBasics USB 2.0 - A-Male to A-Female Exte...       74976.0     4.5
# 4  AmazonBasics USB 2.0 - A-Male to A-Female Exte...       74976.0     4.5
# 5  Crucial BX500 240GB 3D NAND SATA 6.35 cm (2.5-...       92925.0     4.5
# 6  AmazonBasics USB 2.0 Extension Cable for Perso...       74977.0     4.5

# %% [markdown]
# ### <b><u>Correlation </b></u>

# %% [markdown]
# #### Scatter plot - Discounted Price & Rating

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['discounted_price'], df['rating'], alpha=0.5)
plt.xlabel('Discounted Price')
plt.ylabel('Rating')
plt.title('Correlation between Discounted Price and Rating')

# Adding a line of best fit
m, b = np.polyfit(df['discounted_price'], df['rating'], 1)
plt.plot(df['discounted_price'], m * df['discounted_price'] + b, color='red')

plt.show()

# %%
print("Number of Main_Category:",len(df['main_category'].unique()))
print(df['main_category'].value_counts())
# Out:
# Number of Main_Category: 9
# main_category
# Electronics              526
# Computers&Accessories    451
# Home&Kitchen             447
# OfficeProducts            31
# MusicalInstruments         2
# HomeImprovement            2
# Toys&Games                 1
# Car&Motorbike              1
# Health&PersonalCare        1
# Name: count, dtype: int64

# %%
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(18, 15))

# scatter plot in a 3x3 grid
categories = df['main_category'].unique()
for i, category in enumerate(categories):
    ax = axes[i // 3, i % 3]  # Access subplots in grid
    subset = df[df['main_category'] == category]
    
    # Scatter plot for each main category with a trend line
    sns.scatterplot(x=subset['discounted_price'], y=subset['rating'], ax=ax, alpha=0.6, label=f'{category} Ratings')
    m, b = np.polyfit(subset['discounted_price'], subset['rating'], 1)
    ax.plot(subset['discounted_price'], m * subset['discounted_price'] + b, color='red', label='Trend Line')
    
    ax.set_title(f'Discounted Price vs Rating - {category}')
    ax.set_xlabel('Discounted Price')
    ax.set_ylabel('Rating')
    ax.legend()

plt.tight_layout()
plt.show()
# Out:
# /var/folders/ny/3ddtqtxd3b19_82c44nv19bh0000gn/T/ipykernel_23329/1189796913.py:11: RankWarning: Polyfit may be poorly conditioned
#   m, b = np.polyfit(subset['discounted_price'], subset['rating'], 1)
# /var/folders/ny/3ddtqtxd3b19_82c44nv19bh0000gn/T/ipykernel_23329/1189796913.py:11: RankWarning: Polyfit may be poorly conditioned
#   m, b = np.polyfit(subset['discounted_price'], subset['rating'], 1)
# /var/folders/ny/3ddtqtxd3b19_82c44nv19bh0000gn/T/ipykernel_23329/1189796913.py:11: RankWarning: Polyfit may be poorly conditioned
#   m, b = np.polyfit(subset['discounted_price'], subset['rating'], 1)

# %% [markdown]
# #### Scatter plot - Actual Price & Rating

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['actual_price'], df['rating'], alpha=0.5)
plt.xlabel('Actual Price')
plt.ylabel('Rating')
plt.title('Correlation between Actual Price and Rating')

# Adding a line of best fit
m, b = np.polyfit(df['actual_price'], df['rating'], 1)
plt.plot(df['actual_price'], m * df['actual_price'] + b, color='red')

plt.show()

# %%
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(18, 15))

# scatter plot in a 3x3 grid
categories = df['main_category'].unique()
for i, category in enumerate(categories):
    ax = axes[i // 3, i % 3]  # Access subplots in grid
    subset = df[df['main_category'] == category]
    
    # Scatter plot for each main category with a trend line
    sns.scatterplot(x=subset['actual_price'], y=subset['rating'], ax=ax, alpha=0.6, label=f'{category} Ratings')
    m, b = np.polyfit(subset['actual_price'], subset['rating'], 1)
    ax.plot(subset['actual_price'], m * subset['actual_price'] + b, color='red', label='Trend Line')
    
    ax.set_title(f'Actual Price vs Rating - {category}')
    ax.set_xlabel('Actual Price')
    ax.set_ylabel('Rating')
    ax.legend()

plt.tight_layout()
plt.show()
# Out:
# /var/folders/ny/3ddtqtxd3b19_82c44nv19bh0000gn/T/ipykernel_23329/1756412996.py:11: RankWarning: Polyfit may be poorly conditioned
#   m, b = np.polyfit(subset['actual_price'], subset['rating'], 1)
# /var/folders/ny/3ddtqtxd3b19_82c44nv19bh0000gn/T/ipykernel_23329/1756412996.py:11: RankWarning: Polyfit may be poorly conditioned
#   m, b = np.polyfit(subset['actual_price'], subset['rating'], 1)
# /var/folders/ny/3ddtqtxd3b19_82c44nv19bh0000gn/T/ipykernel_23329/1756412996.py:11: RankWarning: Polyfit may be poorly conditioned
#   m, b = np.polyfit(subset['actual_price'], subset['rating'], 1)

# %% [markdown]
# #### Scatter plot - Discounted Percentage & Rating

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['discount_percentage'], df['rating'], alpha=0.5)
plt.xlabel('Discounted percentage')
plt.ylabel('Rating')
plt.title('Correlation between Discounted percentage and Rating')

# Adding a line of best fit
m, b = np.polyfit(df['discount_percentage'], df['rating'], 1)
plt.plot(df['discount_percentage'], m * df['discount_percentage'] + b, color='red')

plt.show()

# %%
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(18, 15))

#  scatter plot in a 3x3 grid
categories = df['main_category'].unique()
for i, category in enumerate(categories):
    ax = axes[i // 3, i % 3]  # Access subplots in grid
    subset = df[df['main_category'] == category]
    
    sns.scatterplot(x=subset['discount_percentage'], y=subset['rating'], ax=ax, alpha=0.6, label=f'{category} Ratings')
    
    if len(subset) > 1 and subset['discount_percentage'].std() > 0:
        m, b = np.polyfit(subset['discount_percentage'], subset['rating'], 1)
        ax.plot(subset['discount_percentage'], m * subset['discount_percentage'] + b, color='red', label='Trend Line')
    
    ax.set_title(f'Discount Percentage vs Rating - {category}')
    ax.set_xlabel('Discount Percentage')
    ax.set_ylabel('Rating')
    ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Sentiment Analysis

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link', 'sub_category',
#        'main_category', 'cluster'],
#       dtype='object')

# %%
df['review_content']
# Out:
# 0       Looks durable Charging is fine tooNo complains...
# 1       I ordered this cable to connect my phone to An...
# 2       Not quite durable and sturdy,https://m.media-a...
# 3       Good product,long wire,Charges good,Nice,I bou...
# 4       Bought this instead of original apple, does th...
#                               ...
# 1460    I received product without spanner,Excellent p...
# 1461    ok,got everything as mentioned but the measuri...
# 1462    plastic but cool body ,u have to find sturdy s...
# 1463    I have installed this in my kitchen working fi...
# 1464    It does it job perfectly..only issue is temp c...
# Name: review_content, Length: 1462, dtype: object

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd
import nltk

# Ensure the necessary NLTK data files are downloaded
nltk.download('vader_lexicon')

# Initialize VADER sentiment analyzer
sid = SentimentIntensityAnalyzer()

df['sentiment_scores'] = df['review_content'].apply(lambda review: sid.polarity_scores(review))

df['compound_score'] = df['sentiment_scores'].apply(lambda score_dict: score_dict['compound'])

# Classify sentiment based on compound score
df['sentiment'] = df['compound_score'].apply(lambda score: 'positive' if score >= 0.05 else 'negative' if score <= -0.05 else 'neutral')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/suminlee/nltk_data...

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# positive    1378
# negative      74
# neutral       10
# Name: count, dtype: int64
