# %% [markdown]
# # Word2Vec
#
# * Word2Vec is a neural-network based method to learn *word embeddings*.
# * It converts words into numerical vectors, which can capture semantic meanings (i.e., synonyms and analogies).
# * It is based on the idea that __similar words appear in similar contexts__ (유사한 의미를 가진 단어는 유사한 맥락에서 발생할 가능성이 더 높다).
# * Word2Vec has two main approaches:
#     - Continuous Bag of Words (CBOW): Predicts the center word based on its surrounding words.
#     - Skip-gram: Predicts surrounding words based on the center word.

# %%
"""
    Gensim is a widely used library for topic modeling (which we do not cover in this course).
    Meanwhile, it supports various word embedding models,
     which I find sufficient to demonstrate its effectiveness.

    Reference: https://radimrehurek.com/gensim/
    gensim은 topic modeling에 주로 쓰이는 library이다. 다양한 단어 임베딩 모델을 지원함.
"""

# !pip show gensim  # `pip install gensim` if not installed
# Out:
# Name: gensim
# Version: 4.3.3
# Summary: Python framework for fast Vector Space Modelling
# Home-page: https://radimrehurek.com/gensim/
# Author: Radim Rehurek
# Author-email: me@radimrehurek.com
# License: LGPL-2.1-only
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: numpy, scipy, smart-open
# Required-by:

# %%
import os
import re
import nltk
import gensim

from gensim.utils import simple_preprocess  # helps preprocessing and tokenization
from nltk.tokenize import sent_tokenize     # used for splitting long documents into sentences.

# %%
nltk.download('punkt') # ‘punkt’ 토크나이저 모델을 다운로드
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ## 1. Data: [Alice’s Adventures in Wonderland](https://www.gutenberg.org/files/11/11-0.txt)

# %% [markdown]
# ### 1-1. Load the corpus

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/2024-2 딥러닝/E. Vector Representations of Text/"
# Out:
# /content/drive/MyDrive/Colab Notebooks/2024-2 딥러닝/E. Vector Representations of Text

# %%
# %ls
# Out:
# 'Alice’s Adventures in Wonderland_text file.txt'   word2vec_model2.model   word2vec_model.model
#  word2vec_from_scratch_using_gensim.ipynb          word2vec_model3

# %%
# txt_file = "./Alice’s Adventures in Wonderland_text file.txt"
txt_file = "/content/drive/My Drive/Colab Notebooks/2024-2 딥러닝/E. Vector Representations of Text/Alice’s Adventures in Wonderland_text file.txt"
assert os.path.isfile(txt_file), "Make sure you fix the path to the file."

# %%
with open(txt_file, 'r', encoding='utf-8') as file:
    corpus = file.readlines() # # 파일의 모든 라인을 읽어서 리스트에 저장; [line1, line2, ...]
    corpus = corpus[30:3380]  # 31번 라인부터 3380번 라인만 사용

corpus = ''.join(corpus)      # 라인들을 하나의 문자열로 결합. [line1, line2, ...] -> "line1 line2 ..."

# %%
print(corpus[:100])  # first 100 characters
# Out:
# CHAPTER I.
# Down the Rabbit-Hole
#
#
# Alice was beginning to get very tired of sitting by her sister on

# %%
print(corpus[-100:])  # last 100 characters
# Out:
# nd a pleasure in all
# their simple joys, remembering her own child-life, and the happy summer
# days.

# %% [markdown]
# ### 1-2. Preprocess the corpus

# %%
corpus = re.sub(r"[^a-zA-Z\s\s+.,?!-]", '', corpus)  # a-zA-Z: 영어 알파벳, \s: 공백, \s+: 하나 이상의 연속된 공백. ^는 부정을 의미: corpus에서 리스트 안에 있는 것 빼고 모두 제거
corpus = corpus.replace('\n', ' ')  # 줄바꿈을 공백으로 변경
corpus = re.sub("\s\s+", " ", corpus)  # 2개 이상 연속된 공백을 공백으로 변경(.e.g, 'the    fox' -> 'the fox')

# %%
print(corpus)  # it's still a very long string
# Out:
# CHAPTER I. Down the Rabbit-Hole Alice was beginning to get very tired of sitting by her sister on the bank, and of having nothing to do once or twice she had peeped into the book her sister was reading, but it had no pictures or conversations in it, and what is the use of a book, thought Alice without pictures or conversations? So she was considering in her own mind as well as she could, for the hot day made her feel very sleepy and stupid, whether the pleasure of making a daisy-chain would be worth the trouble of getting up and picking the daisies, when suddenly a White Rabbit with pink eyes ran close by her. There was nothing so very remarkable in that nor did Alice think it so very much out of the way to hear the Rabbit say to itself, Oh dear! Oh dear! I shall be late! when she thought it over afterwards, it occurred to her that she ought to have wondered at this, but at the time it all seemed quite natural but when the Rabbit actually took a watch out of its waistcoat-pocket, and looked at it, and then hurried on, Alice started to her feet, for it flashed across her mind that she had never before seen a rabbit with either a waistcoat-pocket, or a watch to take out of it, and burning with curiosity, she ran across the field after it, and fortunately was just in time to see it pop down a large rabbit-hole under the hedge. In another moment down went Alice after it, never once considering how in the world she was to get out again. The rabbit-hole went straight on like a tunnel for some way, and then dipped suddenly down, so suddenly that Alice had not a moment to think about stopping herself before she found herself falling down a very deep well. Either the well was very deep, or she fell very slowly, for she had plenty of time as she went down to look about her and to wonder what was going to happen next. First, she tried to look down and make out what she was coming to, but it was too dark to see anything then she looked at the sides of the well, and noticed that they were filled with cupboards and book-shelves here and there she saw maps and pictures hung upon pegs. She took down a jar from one of the shelves as she passed it was labelled ORANGE MARMALADE, but to her great disappointment it was empty she did not like to drop the jar for fear of killing somebody underneath, so managed to put it into one of the cupboards as she fell past it. Well! thought Alice to herself, after such a fall as this, I shall think nothing of tumbling down stairs! How brave theyll all think me at home! Why, I wouldnt say anything about it, even if I fell off the top of the house! Which was very likely true. Down, down, down. Would the fall never come to an end? I wonder how many miles Ive fallen by this time? she said aloud. I must be getting somewhere near the centre of the earth. Let me see that would be four thousand miles down, I think for, you see, Alice had learnt several things of this sort in her lessons in the schoolroom, and though this was not a very good opportunity for showing off her knowledge, as there was no one to listen to her, still it was good practice to say it over yes, thats about the right distancebut then I wonder what Latitude or Longitude Ive got to? Alice had no idea what Latitude was, or Longitude either, but thought they were nice grand words to say. Presently she began again. I wonder if I shall fall right through the earth! How funny itll seem to come out among the people that walk with their heads downward! The Antipathies, I think she was rather glad there was no one listening, this time, as it didnt sound at all the right word but I shall have to ask them what the name of the country is, you know. Please, Maam, is this New Zealand or Australia? and she tried to curtsey as she spokefancy curtseying as youre falling through the air! Do you think you could manage it? And what an ignorant little girl shell think me for asking! No, itll never do to ask perhaps I shall see it written up somewhere. Down, down, down. ...

# %% [markdown]
# ### 1-3. Split corpus into sentences

# %%
# from nltk.tokenize import sent_tokenize
# LookupError -> nltk.download('punkt_tab')

sentences = sent_tokenize(corpus)  # corpus를 문장 단위로 나누기(구두점(마침표, 물음표, 느낌표 등) 기준으로)
print(len(sentences))
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# 1625

# %% [markdown]
# ## 단어 단위 토큰화, 구두점 없애기, 소문자화

# %%
"""
    We still need to:
        - tokenize each sentence into a list of words,
        - remove the punctuations,
        - and lowercase each word.
"""

sentences[:10]  # we still need to remove the punctuations, and lowercase the words
# Out:
# ['CHAPTER I.',
#  'Down the Rabbit-Hole Alice was beginning to get very tired of sitting by her sister on the bank, and of having nothing to do once or twice she had peeped into the book her sister was reading, but it had no pictures or conversations in it, and what is the use of a book, thought Alice without pictures or conversations?',
#  'So she was considering in her own mind as well as she could, for the hot day made her feel very sleepy and stupid, whether the pleasure of making a daisy-chain would be worth the trouble of getting up and picking the daisies, when suddenly a White Rabbit with pink eyes ran close by her.',
#  'There was nothing so very remarkable in that nor did Alice think it so very much out of the way to hear the Rabbit say to itself, Oh dear!',
#  'Oh dear!',
#  'I shall be late!',
#  'when she thought it over afterwards, it occurred to her that she ought to have wondered at this, but at the time it all seemed quite natural but when the Rabbit actually took a watch out of its waistcoat-pocket, and looked at it, and then hurried on, Alice started to her feet, for it flashed across her mind that she had never before seen a rabbit with either a waistcoat-pocket, or a watch to take out of it, and burning with curiosity, she ran across the field after it, and fortunately was just in time to see it pop down a large rabbit-hole under the hedge.',
#  'In another moment down went Alice after it, never once considering how in the world she was to get out again.',
#  'The rabbit-hole went straight on like a tunnel for some way, and then dipped suddenly down, so suddenly that Alice had not a moment to think about stopping herself before she found herself falling down a very deep well.',
#  'Either the well was very deep, or she fell very slowly, for she had plenty of time as she went down to look about her and to wonder what was going to happen next.']

# %% [markdown]
# ### 1-4. Tokenize sentences into a list of words.

# %%
# from gensim.utils import simple_preprocess -> 단어 토큰화, 구두점 없애기, 소문자화 한번에 해줌.

tokenized_sentences = [simple_preprocess(sent) for sent in sentences] # 문장 내 단어 토큰화 -> "This is a test sentence." -> ['this', 'is', 'a', 'test', 'sentence']

# %%
for i, sent in enumerate(tokenized_sentences):
    print(f"({i:>2})", sent) # i:>2 -> 2자리 오른쪽 정렬
    if i == 30:  # check only the first 30 sentences
        break
# Out:
# ( 0) ['chapter']
# ( 1) ['down', 'the', 'rabbit', 'hole', 'alice', 'was', 'beginning', 'to', 'get', 'very', 'tired', 'of', 'sitting', 'by', 'her', 'sister', 'on', 'the', 'bank', 'and', 'of', 'having', 'nothing', 'to', 'do', 'once', 'or', 'twice', 'she', 'had', 'peeped', 'into', 'the', 'book', 'her', 'sister', 'was', 'reading', 'but', 'it', 'had', 'no', 'pictures', 'or', 'conversations', 'in', 'it', 'and', 'what', 'is', 'the', 'use', 'of', 'book', 'thought', 'alice', 'without', 'pictures', 'or', 'conversations']
# ( 2) ['so', 'she', 'was', 'considering', 'in', 'her', 'own', 'mind', 'as', 'well', 'as', 'she', 'could', 'for', 'the', 'hot', 'day', 'made', 'her', 'feel', 'very', 'sleepy', 'and', 'stupid', 'whether', 'the', 'pleasure', 'of', 'making', 'daisy', 'chain', 'would', 'be', 'worth', 'the', 'trouble', 'of', 'getting', 'up', 'and', 'picking', 'the', 'daisies', 'when', 'suddenly', 'white', 'rabbit', 'with', 'pink', 'eyes', 'ran', 'close', 'by', 'her']
# ( 3) ['there', 'was', 'nothing', 'so', 'very', 'remarkable', 'in', 'that', 'nor', 'did', 'alice', 'think', 'it', 'so', 'very', 'much', 'out', 'of', 'the', 'way', 'to', 'hear', 'the', 'rabbit', 'say', 'to', 'itself', 'oh', 'dear']
# ( 4) ['oh', 'dear']
# ( 5) ['shall', 'be', 'late']
# ( 6) ['when', 'she', 'thought', 'it', 'over', 'afterwards', 'it', 'occurred', 'to', 'her', 'that', 'she', 'ought', 'to', 'have', 'wondered', 'at', 'this', 'but', 'at', 'the', 'time', 'it', 'all', 'seemed', 'quite', 'natural', 'but', 'when', 'the', 'rabbit', 'actually', 'took', 'watch', 'out', 'of', 'its', 'waistcoat', 'pocket', 'and', 'looked', 'at', 'it', 'and', 'then', 'hurried', 'on', 'alice', 'started', 'to', 'her', 'feet', 'for', 'it', 'flashed', 'across', 'her', 'mind', 'that', 'she', 'had', 'never', 'before', 'seen', 'rabbit', 'with', 'either', 'waistcoat', 'pocket', 'or', 'watch', 'to', 'take', 'out', 'of', 'it', 'and', 'burning', 'with', 'curiosity', 'she', 'ran', 'across', 'the', 'field', 'after', 'it', 'and', 'fortunately', 'was', 'just', 'in', 'time', 'to', 'see', 'it', 'pop', 'down', 'large', 'rabbit', 'hole', 'under', 'the', 'hedge']
# ( 7) ['in', 'another', 'moment', 'down', 'went', 'alice', 'after', 'it', 'never', 'once', 'considering', 'how', 'in', 'the', 'world', 'she', 'was', 'to', 'get', 'out', 'again']
# ( 8) ['the', 'rabbit', 'hole', 'went', 'straight', 'on', 'like', 'tunnel', 'for', 'some', 'way', 'and', 'then', 'dipped', 'suddenly', 'down', 'so', 'suddenly', 'that', 'alice', 'had', 'not', 'moment', 'to', 'think', 'about', 'stopping', 'herself', 'before', 'she', 'found', 'herself', 'falling', 'down', 'very', 'deep', 'well']
# ( 9) ['either', 'the', 'well', 'was', 'very', 'deep', 'or', 'she', 'fell', 'very', 'slowly', 'for', 'she', 'had', 'plenty', 'of', 'time', 'as', 'she', 'went', 'down', 'to', 'look', 'about', 'her', 'and', 'to', 'wonder', 'what', 'was', 'going', 'to', 'happen', 'next']
# (10) ['first', 'she', 'tried', 'to', 'look', 'down', 'and', 'make', 'out', 'what', 'she', 'was', 'coming', 'to', 'but', 'it', 'was', 'too', 'dark', 'to', 'see', 'anything', 'then', 'she', 'looked', 'at', 'the', 'sides', 'of', 'the', 'well', 'and', 'noticed', 'that', 'they', 'were', 'filled', 'with', 'cupboards', 'and', 'book', 'shelves', 'here', 'and', 'there', 'she', 'saw', 'maps', 'and', 'pictures', 'hung', 'upon', 'pegs']
# (11) ['she', 'took', 'down', 'jar', 'from', 'one', 'of', 'the', 'shelves', 'as', 'she', 'passed', 'it', 'was', 'labelled', 'orange', 'marmalade', 'but', 'to', 'her', 'great', 'disappointment', 'it', 'was', 'empty', 'she', 'did', 'not', 'like', 'to', 'drop', 'the', 'jar', 'for', 'fear', 'of', 'killing', 'somebody', 'underneath', 'so', 'managed', 'to', 'put', 'it', 'into', 'one', 'of', 'the', 'cupboards', 'as', 'she', 'fell', 'past', 'it']
# (12) ['well']
# (13) ['thought', 'alice', 'to', 'herself', 'after', 'such', 'fall', 'as', 'this', 'shall', 'think', 'nothing', 'of', 'tumbling', 'down', 'stairs']
# (14) ['how', 'brave', 'theyll', 'all', 'think', 'me', 'at', 'home']
# (15) ['why', 'wouldnt', 'say', 'anything', 'about', 'it', 'even', 'if', 'fell', 'off', 'the', 'top', 'of', 'the', 'house']
# (16) ['which', 'was', 'very', 'likely', 'true']
# (17) ['down', 'down', 'down']
# (18) ['would', 'the', 'fall', 'never', 'come', 'to', 'an', 'end']
# (19) ['wonder', 'how', 'many', 'miles', 'ive', 'fallen', 'by', 'this', 'time']
# (20) ['she', 'said', 'aloud']
# (21) ['must', 'be', 'getting', 'somewhere', 'near', 'the', 'centre', 'of', 'the', 'earth']
# (22) ['let', 'me', 'see', 'that', 'would', 'be', 'four', 'thousand', 'miles', 'down', 'think', 'for', 'you', 'see', 'alice', 'had', 'learnt', 'several', 'things', 'of', 'this', 'sort', 'in', 'her', 'lessons', 'in', 'the', 'schoolroom', 'and', 'though', 'this', 'was', 'not', 'very', 'good', 'opportunity', 'for', 'showing', 'off', 'her', 'knowledge', 'as', 'there', 'was', 'no', 'one', 'to', 'listen', 'to', 'her', 'still', 'it', 'was', 'good', 'practice', 'to', 'say', 'it', 'over', 'yes', 'thats', 'about', 'the', 'right', 'distancebut', 'then', 'wonder', 'what', 'latitude', 'or', 'longitude', 'ive', 'got', 'to']
# (23) ['alice', 'had', 'no', 'idea', 'what', 'latitude', 'was', 'or', 'longitude', 'either', 'but', 'thought', 'they', 'were', 'nice', 'grand', 'words', 'to', 'say']
# (24) ['presently', 'she', 'began', 'again']
# (25) ['wonder', 'if', 'shall', 'fall', 'right', 'through', 'the', 'earth']
# (26) ['how', 'funny', 'itll', 'seem', 'to', 'come', 'out', 'among', 'the', 'people', 'that', 'walk', 'with', 'their', 'heads', 'downward']
# (27) ['the', 'antipathies', 'think', 'she', 'was', 'rather', 'glad', 'there', 'was', 'no', 'one', 'listening', 'this', 'time', 'as', 'it', 'didnt', 'sound', 'at', 'all', 'the', 'right', 'word', 'but', 'shall', 'have', 'to', 'ask', 'them', 'what', 'the', 'name', 'of', 'the', 'country', 'is', 'you', 'know']
# (28) ['please', 'maam', 'is', 'this', 'new', 'zealand', 'or', 'australia']
# (29) ['and', 'she', 'tried', 'to', 'curtsey', 'as', 'she', 'spokefancy', 'curtseying', 'as', 'youre', 'falling', 'through', 'the', 'air']
# (30) ['do', 'you', 'think', 'you', 'could', 'manage', 'it']

# %% [markdown]
# ## 2. Word2Vec

# %% [markdown]
# ### 2-1. Model Training

# %%
from gensim.models import Word2Vec

# Train the Word2Vec model
model = Word2Vec(
    sentences=tokenized_sentences,  # 단어 단위 토큰화된 데이터
    vector_size=100,                # 임베딩 벡터 차원(input, output embedding vector)
    window=5,                       # Context window size
    min_count=2,                    # 모델 학습에 포함할 단어의 최소 빈도 수
    workers=4,                      # Number of worker threads for training = 병렬화를 위한 워커 스레드 수
    sg=0,                           # CBOW=0, Skip-gram=1
    epochs=300,                     # larger the number of epochs, the longer the training
)

# Check the vocabulary size
print("Vocabulary size:", len(model.wv.key_to_index))
# Out:
# Vocabulary size: 1476

# %% [markdown]
# ### 2-2. Vocabulary

# %% [markdown]
# #### 특정 단어의 index 불러오기

# %%
"""
    In NLP with deep learning, it is a standard to represent
    the vocabulary as a python dictionary, where the keys are
    the 'words', and the values are integer indexes.
"""

model.wv.key_to_index  # dictionary
# Out:
# {'the': 0,
#  'and': 1,
#  'to': 2,
#  'she': 3,
#  'it': 4,
#  'of': 5,
#  'said': 6,
#  'alice': 7,
#  'in': 8,
#  'you': 9,
#  'was': 10,
#  'that': 11,
#  'as': 12,
#  'her': 13,
#  'at': 14,
#  'on': 15,
#  'with': 16,
#  'all': 17,
#  'had': 18,
#  'but': 19,
#  'for': 20,
#  'so': 21,
#  'be': 22,
#  'not': 23,
#  'very': 24,
#  'what': 25,
#  'this': 26,
#  'little': 27,
#  'they': 28,
#  'he': 29,
#  'out': 30,
#  'its': 31,
#  'is': 32,
#  'one': 33,
#  'down': 34,
#  'up': 35,
#  'his': 36,
#  'if': 37,
#  'about': 38,
#  'then': 39,
#  'no': 40,
#  'were': 41,
#  'like': 42,
#  'know': 43,
#  'them': 44,
#  'went': 45,
#  'herself': 46,
#  'would': 47,
#  'again': 48,
#  'have': 49,
#  'do': 50,
#  'when': 51,
#  'could': 52,
#  'or': 53,
#  'there': 54,
#  'thought': 55,
#  'off': 56,
#  'time': 57,
#  'me': 58,
#  'queen': 59,
#  'into': 60,
#  'see': 61,
#  'how': 62,
#  'your': 63,
#  'did': 64,
#  'well': 65,
#  'who': 66,
#  'king': 67,
#  'dont': 68,
#  'my': 69,
#  'began': 70,
#  'now': 71,
#  'by': 72,
#  'an': 73,
#  'im': 74,
#  'turtle': 75,
#  'way': 76,
#  'mock': 77,
#  'gryphon': 78,
#  'quite': 79,
#  'hatter': 80,
#  'think': 81,
#  'are': 82,
#  'their': 83,
#  'just': 84,
#  'some': 85,
#  'much': 86,
#  'go': 87,
#  'say': 88,
#  'which': 89,
#  'thing': 90,
#  'here': 91,
#  'only': 92,
#  'first': 93,
#  'head': 94,
#  'more': 95,
#  'voice': 96,
#  'rabbit': 97,
#  'get': 98,
#  'never': 99,
#  'come': 100,
#  'got': 101,
#  'looked': 102,
#  'must': 103,
#  'after': 104,
#  'such': 105,
#  'round': 106,
#  'him': 107,
#  'why': 108,
#  'two': 109,
#  'over': 110,
#  'came': 111,
#  'tone': 112,
#  'duchess': 113,
#  'mouse': 114,
#  'other': 115,
#  'great': 116,
#  'dormouse': 117,
#  'back': 118,
#  'any': 119,
#  'oh': 120,
#  'been': 121,
#  'before': 122,
#  'from': 123,
#  'cat': 124,
#  'nothing': 125,
#  'ive': 126,
#  'can': 127,
#  'last': 128,
#  'large': 129,
#  'march': 130,
#  'ill': 131,
#  'thats': 132,
#  'tell': 133,
#  'right': 134,
#  'found': 135,
#  'long': 136,
#  'once': 137,
#  'looking': 138,
#  'put': 139,
#  'will': 140,
#  'hare': 141,
#  'white': 142,
#  'heard': 143,
#  'made': 144,
#  'next': 145,
#  'day': 146,
#  'dear': 147,
#  'we': 148,
#  'replied': 149,
#  'door': 150,
#  'look': 151,
#  'moment': 152,
#  'things': 153,
#  'three': 154,
#  'might': 155,
#  'cant': 156,
#  'eyes': 157,
#  'should': 158,
#  'caterpillar': 159,
#  'good': 160,
#  'going': 161,
#  'seemed': 162,
#  'poor': 163,
#  'make': 164,
#  'upon': 165,
#  'too': 166,
#  'course': 167,
#  'rather': 168,
#  'soon': 169,
#  'shall': 170,
#  'away': 171,
#  'without': 172,
#  'theres': 173,
#  'while': 174,
#  'wont': 175,
#  'than': 176,
#  'same': 177,
#  'sure': 178,
#  'took': 179,
#  'youre': 180,
#  'added': 181,
#  'half': 182,
#  'felt': 183,
#  'jury': 184,
#  'getting': 185,
#  'ever': 186,
#  'yet': 187,
#  'another': 188,
#  'minute': 189,
#  'till': 190,
#  'hand': 191,
#  'wish': 192,
#  'find': 193,
#  'take': 194,
#  'words': 195,
#  'however': 196,
#  'cried': 197,
#  'sort': 198,
#  'being': 199,
#  'anything': 200,
#  'please': 201,
#  'curious': 202,
#  'feet': 203,
#  'tried': 204,
#  'old': 205,
#  'court': 206,
#  'use': 207,
#  'tea': 208,
#  'house': 209,
#  'even': 210,
#  'table': 211,
#  'wonder': 212,
#  'eat': 213,
#  'soup': 214,
#  'something': 215,
#  'let': 216,
#  'perhaps': 217,
#  'sat': 218,
#  'enough': 219,
#  'end': 220,
#  'talking': 221,
#  'side': 222,
#  'question': 223,
#  'asked': 224,
#  'high': 225,
#  'bit': 226,
#  'indeed': 227,
#  'hastily': 228,
#  'turned': 229,
#  'under': 230,
#  'doesnt': 231,
#  'spoke': 232,
#  'ran': 233,
#  'low': 234,
#  'knew': 235,
#  'am': 236,
#  'idea': 237,
#  'cats': 238,
#  'done': 239,
#  'garden': 240,
#  'saying': 241,
#  'arm': 242,
#  'gave': 243,
#  'because': 244,
#  'called': 245,
#  'air': 246,
#  'near': 247,
#  'saw': 248,
#  'beautiful': 249,
#  'anxiously': 250,
#  'left': 251,
#  'face': 252,
#  'mad': 253,
#  'certainly': 254,
#  'set': 255,
#  'itself': 256,
#  'speak': 257,
#  'didnt': 258,
#  'us': 259,
#  'better': 260,
#  'hear': 261,
#  'silence': 262,
#  'ought': 263,
#  'talk': 264,
#  'suppose': 265,
#  'sea': 266,
#  'these': 267,
#  'change': 268,
#  'trying': 269,
#  'both': 270,
#  'seen': 271,
#  'remember': 272,
#  'through': 273,
#  'whole': 274,
#  'theyre': 275,
#  'still': 276,
#  'wouldnt': 277,
#  'close': 278,
#  'dance': 279,
#  'people': 280,
#  'yes': 281,
#  'suddenly': 282,
#  'grow': 283,
#  'kept': 284,
#  'footman': 285,
#  'really': 286,
#  'beginning': 287,
#  'baby': 288,
#  'size': 289,
#  'cook': 290,
#  'begin': 291,
#  'where': 292,
#  'may': 293,
#  'room': 294,
#  'gone': 295,
#  'far': 296,
#  'dodo': 297,
#  'behind': 298,
#  'always': 299,
#  'give': 300,
#  'deal': 301,
#  'queer': 302,
#  'turning': 303,
#  'pigeon': 304,
#  'finished': 305,
#  'hardly': 306,
#  'game': 307,
#  'among': 308,
#  'life': 309,
#  'many': 310,
#  'every': 311,
#  'bill': 312,
#  'best': 313,
#  'hands': 314,
#  'used': 315,
#  'try': 316,
#  'afraid': 317,
#  'chapter': 318,
#  'majesty': 319,
#  'id': 320,
#  'alices': 321,
#  'waited': 322,
#  'minutes': 323,
#  'heads': 324,
#  'nearly': 325,
#  'tears': 326,
#  'whether': 327,
#  'child': 328,
#  'mind': 329,
#  'book': 330,
#  'dinah': 331,
#  'glad': 332,
#  'makes': 333,
#  'ask': 334,
#  'pig': 335,
#  'growing': 336,
#  'turn': 337,
#  'keep': 338,
#  'hurry': 339,
#  'wasnt': 340,
#  'though': 341,
#  'thinking': 342,
#  'read': 343,
#  'hurried': 344,
#  'walked': 345,
#  'else': 346,
#  'sight': 347,
#  'foot': 348,
#  'offended': 349,
#  'own': 350,
#  'soldiers': 351,
#  'lessons': 352,
#  'either': 353,
#  'party': 354,
#  'box': 355,
#  'creatures': 356,
#  'youd': 357,
#  'pool': 358,
#  'repeated': 359,
#  'word': 360,
#  'gloves': 361,
#  'everything': 362,
#  'small': 363,
#  'bottle': 364,
#  'remarked': 365,
#  'mouth': 366,
#  'opened': 367,
#  'those': 368,
#  'rest': 369,
#  'witness': 370,
#  'remark': 371,
#  'yourself': 372,
#  'fan': 373,
#  'mean': 374,
#  'explain': 375,
#  'children': 376,
#  'name': 377,
#  'sitting': 378,
#  'having': 379,
#  'glass': 380,
#  'waiting': 381,
#  'serpent': 382,
#  'call': 383,
#  'few': 384,
#  'want': 385,
#  'reason': 386,
#  'rate': 387,
#  'help': 388,
#  'join': 389,
#  'shouted': 390,
#  'hall': 391,
#  'conversation': 392,
#  'mine': 393,
#  'coming': 394,
#  'does': 395,
#  'couldnt': 396,
#  'tail': 397,
#  'interrupted': 398,
#  'continued': 399,
#  'answer': 400,
#  'matter': 401,
#  'shook': 402,
#  'believe': 403,
#  'leave': 404,
#  'knave': 405,
#  'key': 406,
#  'together': 407,
#  'butter': 408,
#  'different': 409,
#  'tree': 410,
#  'croquet': 411,
#  'hold': 412,
#  'timidly': 413,
#  'against': 414,
#  'puzzled': 415,
#  'angrily': 416,
#  'birds': 417,
#  'least': 418,
#  'asleep': 419,
#  'ready': 420,
#  'havent': 421,
#  'slowly': 422,
#  'opportunity': 423,
#  'most': 424,
#  'hadnt': 425,
#  'changed': 426,
#  'mushroom': 427,
#  'each': 428,
#  'moral': 429,
#  'place': 430,
#  'hard': 431,
#  'top': 432,
#  'seem': 433,
#  'story': 434,
#  'appeared': 435,
#  'itll': 436,
#  'pepper': 437,
#  'nobody': 438,
#  'gardeners': 439,
#  'fact': 440,
#  'meaning': 441,
#  'running': 442,
#  'beg': 443,
#  'queens': 444,
#  'bright': 445,
#  'everybody': 446,
#  'sister': 447,
#  'watch': 448,
#  'feel': 449,
#  'exactly': 450,
#  'twinkle': 451,
#  'followed': 452,
#  'noticed': 453,
#  'window': 454,
#  'play': 455,
#  'four': 456,
#  'nose': 457,
#  'happen': 458,
#  'our': 459,
#  'five': 460,
#  'whiting': 461,
#  'live': 462,
#  'work': 463,
#  'eagerly': 464,
#  'hearts': 465,
#  'sit': 466,
#  'dry': 467,
#  'lying': 468,
#  'making': 469,
#  'world': 470,
#  'middle': 471,
#  'learn': 472,
#  'manage': 473,
#  'frightened': 474,
#  'fetch': 475,
#  'treacle': 476,
#  'trial': 477,
#  'has': 478,
#  'others': 479,
#  'begun': 480,
#  'dream': 481,
#  'lory': 482,
#  'wondering': 483,
#  'chin': 484,
#  'stood': 485,
#  'hedgehog': 486,
#  'grown': 487,
#  'bread': 488,
#  'history': 489,
#  'william': 490,
#  'business': 491,
#  'repeat': 492,
#  'cheshire': 493,
#  'myself': 494,
#  'isnt': 495,
#  'deep': 496,
#  'eye': 497,
#  'somebody': 498,
#  'evidence': 499,
#  'draw': 500,
#  'feeling': 501,
#  'song': 502,
#  'surprised': 503,
#  'open': 504,
#  'sir': 505,
#  'lobster': 506,
#  'goes': 507,
#  'shoes': 508,
#  'fish': 509,
#  'kind': 510,
#  'golden': 511,
#  'fall': 512,
#  'lobsters': 513,
#  'distance': 514,
#  'larger': 515,
#  'nonsense': 516,
#  'ground': 517,
#  'hair': 518,
#  'listen': 519,
#  'tired': 520,
#  'hot': 521,
#  'happened': 522,
#  'silent': 523,
#  'generally': 524,
#  'shes': 525,
#  'soooop': 526,
#  'wood': 527,
#  'pleased': 528,
#  'tarts': 529,
#  'pocket': 530,
#  'neck': 531,
#  'drink': 532,
#  'slates': 533,
#  'trees': 534,
#  'written': 535,
#  'subject': 536,
#  'youve': 537,
#  'executed': 538,
#  'broken': 539,
#  'trembling': 540,
#  'exclaimed': 541,
#  'late': 542,
#  'chimney': 543,
#  'melancholy': 544,
#  'politely': 545,
#  'shant': 546,
#  'sleep': 547,
#  'english': 548,
#  'sing': 549,
#  'inches': 550,
#  'jumped': 551,
#  'leaves': 552,
#  'wow': 553,
#  'race': 554,
#  'ear': 555,
#  'forgotten': 556,
#  'youll': 557,
#  'ten': 558,
#  'almost': 559,
#  'youth': 560,
#  'full': 561,
#  'sharp': 562,
#  'roof': 563,
#  'stop': 564,
#  'marked': 565,
#  'chorus': 566,
#  'trouble': 567,
#  'loud': 568,
#  'school': 569,
#  'puppy': 570,
#  'writing': 571,
#  'fell': 572,
#  'times': 573,
#  'seven': 574,
#  'nice': 575,
#  'grin': 576,
#  'pigs': 577,
#  'stupid': 578,
#  'guinea': 579,
#  'piece': 580,
#  'between': 581,
#  'told': 582,
#  'stand': 583,
#  'write': 584,
#  'pardon': 585,
#  'arms': 586,
#  'sentence': 587,
#  'father': 588,
#  'dreadfully': 589,
#  'understand': 590,
#  'himself': 591,
#  'liked': 592,
#  'sneezing': 593,
#  'along': 594,
#  'rose': 595,
#  'altogether': 596,
#  'dare': 597,
#  'whats': 598,
#  'shut': 599,
#  'notice': 600,
#  'finger': 601,
#  'faces': 602,
#  'twice': 603,
#  'nervous': 604,
#  'cut': 605,
#  'prizes': 606,
#  'simple': 607,
#  'fancy': 608,
#  'sleepy': 609,
#  'walking': 610,
#  'speaking': 611,
#  'dropped': 612,
#  'swam': 613,
#  'number': 614,
#  'case': 615,
#  'usual': 616,
#  'morning': 617,
#  'executioner': 618,
#  'water': 619,
#  'ah': 620,
#  'tis': 621,
#  'sudden': 622,
#  'stay': 623,
#  'sadly': 624,
#  'seems': 625,
#  'lets': 626,
#  'strange': 627,
#  'sounded': 628,
#  'nearer': 629,
#  'ears': 630,
#  'important': 631,
#  'kid': 632,
#  'procession': 633,
#  'rule': 634,
#  'pack': 635,
#  'remembered': 636,
#  'crowded': 637,
#  'knee': 638,
#  'adventures': 639,
#  'happens': 640,
#  'whispered': 641,
#  'wrong': 642,
#  'pair': 643,
#  'flamingo': 644,
#  'nine': 645,
#  'angry': 646,
#  'shrill': 647,
#  'until': 648,
#  'animals': 649,
#  'confusion': 650,
#  'sometimes': 651,
#  'become': 652,
#  'home': 653,
#  'across': 654,
#  'sky': 655,
#  'reply': 656,
#  'waving': 657,
#  'eggs': 658,
#  'impatiently': 659,
#  'instantly': 660,
#  'surprise': 661,
#  'sighed': 662,
#  'direction': 663,
#  'asking': 664,
#  'temper': 665,
#  'lizard': 666,
#  'likely': 667,
#  'doing': 668,
#  'young': 669,
#  'aloud': 670,
#  'night': 671,
#  'often': 672,
#  'swim': 673,
#  'moved': 674,
#  'height': 675,
#  'quietly': 676,
#  'hookah': 677,
#  'man': 678,
#  'meant': 679,
#  'finish': 680,
#  'interesting': 681,
#  'drew': 682,
#  'curiosity': 683,
#  'shriek': 684,
#  'new': 685,
#  'passed': 686,
#  'walk': 687,
#  'shouldnt': 688,
#  'taking': 689,
#  'rabbits': 690,
#  'plan': 691,
#  'players': 692,
#  'outside': 693,
#  'difficulty': 694,
#  'puzzling': 695,
#  'besides': 696,
#  'except': 697,
#  'twelve': 698,
#  'mabel': 699,
#  'tiny': 700,
#  'age': 701,
#  'stick': 702,
#  'grass': 703,
#  'shoulder': 704,
#  'ordered': 705,
#  'french': 706,
#  'crumbs': 707,
#  'fast': 708,
#  'held': 709,
#  'shrinking': 710,
#  'alone': 711,
#  'fellow': 712,
#  'thank': 713,
#  'master': 714,
#  'worth': 715,
#  'dead': 716,
#  'escape': 717,
#  'turtles': 718,
#  'bills': 719,
#  'hearing': 720,
#  'doubt': 721,
#  'sounds': 722,
#  'honour': 723,
#  'yer': 724,
#  'digging': 725,
#  'lay': 726,
#  'crowd': 727,
#  'sound': 728,
#  'violently': 729,
#  'capital': 730,
#  'savage': 731,
#  'quadrille': 732,
#  'sharply': 733,
#  'beauootiful': 734,
#  'trials': 735,
#  'hours': 736,
#  'reach': 737,
#  'theyll': 738,
#  'jurors': 739,
#  'lives': 740,
#  'otherwise': 741,
#  'led': 742,
#  'ventured': 743,
#  'deeply': 744,
#  'carried': 745,
#  'taught': 746,
#  'dish': 747,
#  'managed': 748,
#  'days': 749,
#  'kitchen': 750,
#  'paper': 751,
#  'jumping': 752,
#  'officers': 753,
#  'fear': 754,
#  'suppressed': 755,
#  'jurymen': 756,
#  'verses': 757,
#  'hole': 758,
#  'shoulders': 759,
#  'severely': 760,
#  'busily': 761,
#  'sides': 762,
#  'fallen': 763,
#  'perfectly': 764,
#  'none': 765,
#  'several': 766,
#  'sobs': 767,
#  'chance': 768,
#  'questions': 769,
#  'stuff': 770,
#  'decidedly': 771,
#  'earth': 772,
#  'alas': 773,
#  'boots': 774,
#  'grunted': 775,
#  'creature': 776,
#  'taken': 777,
#  'thoughtfully': 778,
#  'true': 779,
#  'porpoise': 780,
#  'pictures': 781,
#  'green': 782,
#  'verse': 783,
#  'care': 784,
#  'screamed': 785,
#  'indignantly': 786,
#  'person': 787,
#  'beat': 788,
#  'second': 789,
#  'less': 790,
#  'answered': 791,
#  'girl': 792,
#  'sigh': 793,
#  'twinkling': 794,
#  'dogs': 795,
#  'theyd': 796,
#  'passage': 797,
#  'solemnly': 798,
#  'says': 799,
#  'confused': 800,
#  'pointing': 801,
#  'pale': 802,
#  'argument': 803,
#  'uncomfortable': 804,
#  'consider': 805,
#  'shore': 806,
#  'run': 807,
#  'duck': 808,
#  'begins': 809,
#  'since': 810,
#  'tale': 811,
#  'judge': 812,
#  'breath': 813,
#  'vanished': 814,
#  'ann': 815,
#  'natural': 816,
#  'bats': 817,
#  'mary': 818,
#  'paws': 819,
#  'frowning': 820,
#  'bottom': 821,
#  'bowed': 822,
#  'miss': 823,
#  'fire': 824,
#  'means': 825,
#  'wanted': 826,
#  'tongue': 827,
#  'short': 828,
#  'thimble': 829,
#  'arches': 830,
#  'bring': 831,
#  'pleaded': 832,
#  'panther': 833,
#  'shaped': 834,
#  'easily': 835,
#  'bat': 836,
#  'joined': 837,
#  'girls': 838,
#  'catch': 839,
#  'dull': 840,
#  'attending': 841,
#  'miles': 842,
#  'tasted': 843,
#  'caught': 844,
#  'mark': 845,
#  'toes': 846,
#  'pie': 847,
#  'pressed': 848,
#  'dears': 849,
#  'peeped': 850,
#  'checked': 851,
#  'opening': 852,
#  'fond': 853,
#  'serpents': 854,
#  'yours': 855,
#  'watching': 856,
#  'tails': 857,
#  'remained': 858,
#  'beheaded': 859,
#  'shaking': 860,
#  'holding': 861,
#  'mouths': 862,
#  'free': 863,
#  'crown': 864,
#  'crab': 865,
#  'obliged': 866,
#  'smaller': 867,
#  'succeeded': 868,
#  'tossing': 869,
#  'reading': 870,
#  'dark': 871,
#  'cake': 872,
#  'roses': 873,
#  'move': 874,
#  'follows': 875,
#  'snail': 876,
#  'pity': 877,
#  'around': 878,
#  'frog': 879,
#  'owl': 880,
#  'expecting': 881,
#  'oclock': 882,
#  'trumpet': 883,
#  'upset': 884,
#  'speech': 885,
#  'past': 886,
#  'handed': 887,
#  'teacup': 888,
#  'red': 889,
#  'fury': 890,
#  'howling': 891,
#  'wrote': 892,
#  'sighing': 893,
#  'instance': 894,
#  'gravely': 895,
#  'repeating': 896,
#  'poison': 897,
#  'hes': 898,
#  'nursing': 899,
#  'cheered': 900,
#  'settled': 901,
#  'list': 902,
#  'rules': 903,
#  'grave': 904,
#  'hoping': 905,
#  'sad': 906,
#  'lived': 907,
#  'impossible': 908,
#  'unimportant': 909,
#  'grinned': 910,
#  'courage': 911,
#  'solemn': 912,
#  'fit': 913,
#  'telescope': 914,
#  'noise': 915,
#  'growl': 916,
#  'verdict': 917,
#  'staring': 918,
#  'met': 919,
#  'eeevening': 920,
#  'legs': 921,
#  'hope': 922,
#  'possibly': 923,
#  'decided': 924,
#  'proper': 925,
#  'mice': 926,
#  'pieces': 927,
#  'candle': 928,
#  'nibbling': 929,
#  'bringing': 930,
#  'further': 931,
#  'filled': 932,
#  'lady': 933,
#  'delight': 934,
#  'advantage': 935,
#  'livery': 936,
#  'spectacles': 937,
#  'considered': 938,
#  'slate': 939,
#  'loudly': 940,
#  'letter': 941,
#  'finding': 942,
#  'stairs': 943,
#  'later': 944,
#  'certain': 945,
#  'faster': 946,
#  'order': 947,
#  'knife': 948,
#  'particular': 949,
#  'sobbing': 950,
#  'figure': 951,
#  'passion': 952,
#  'shell': 953,
#  'real': 954,
#  'guess': 955,
#  'kick': 956,
#  'hurt': 957,
#  'unfortunate': 958,
#  'above': 959,
#  'knocking': 960,
#  'putting': 961,
#  'fun': 962,
#  'plate': 963,
#  'mistake': 964,
#  'mustard': 965,
#  'gently': 966,
#  'throw': 967,
#  'sense': 968,
#  'spread': 969,
#  'moving': 970,
#  'funny': 971,
#  'civil': 972,
#  'themselves': 973,
#  'hoarse': 974,
#  'cakes': 975,
#  'crossed': 976,
#  'doth': 977,
#  'neednt': 978,
#  'eaglet': 979,
#  'whisper': 980,
#  'cause': 981,
#  'below': 982,
#  'twenty': 983,
#  'turns': 984,
#  'tucked': 985,
#  'show': 986,
#  'whatever': 987,
#  'cautiously': 988,
#  'lesson': 989,
#  'whiskers': 990,
#  'nor': 991,
#  'notion': 992,
#  'longer': 993,
#  'stopped': 994,
#  'lost': 995,
#  'forgetting': 996,
#  'elbow': 997,
#  'effect': 998,
#  'hush': 999,
#  ...}

# %%
"""
    Q) What is the index of the word 'was'?
"""

model.wv.key_to_index['was']
# Out:
# 10

# %% [markdown]
# #### 특정 index의 단어 가져오기

# %%
"""
    Sometimes, we wish to retrieve a word by its index.
    The trick is to store the words in a list.
"""

model.wv.index_to_key
# Out:
# ['the',
#  'and',
#  'to',
#  'she',
#  'it',
#  'of',
#  'said',
#  'alice',
#  'in',
#  'you',
#  'was',
#  'that',
#  'as',
#  'her',
#  'at',
#  'on',
#  'with',
#  'all',
#  'had',
#  'but',
#  'for',
#  'so',
#  'be',
#  'not',
#  'very',
#  'what',
#  'this',
#  'little',
#  'they',
#  'he',
#  'out',
#  'its',
#  'is',
#  'one',
#  'down',
#  'up',
#  'his',
#  'if',
#  'about',
#  'then',
#  'no',
#  'were',
#  'like',
#  'know',
#  'them',
#  'went',
#  'herself',
#  'would',
#  'again',
#  'have',
#  'do',
#  'when',
#  'could',
#  'or',
#  'there',
#  'thought',
#  'off',
#  'time',
#  'me',
#  'queen',
#  'into',
#  'see',
#  'how',
#  'your',
#  'did',
#  'well',
#  'who',
#  'king',
#  'dont',
#  'my',
#  'began',
#  'now',
#  'by',
#  'an',
#  'im',
#  'turtle',
#  'way',
#  'mock',
#  'gryphon',
#  'quite',
#  'hatter',
#  'think',
#  'are',
#  'their',
#  'just',
#  'some',
#  'much',
#  'go',
#  'say',
#  'which',
#  'thing',
#  'here',
#  'only',
#  'first',
#  'head',
#  'more',
#  'voice',
#  'rabbit',
#  'get',
#  'never',
#  'come',
#  'got',
#  'looked',
#  'must',
#  'after',
#  'such',
#  'round',
#  'him',
#  'why',
#  'two',
#  'over',
#  'came',
#  'tone',
#  'duchess',
#  'mouse',
#  'other',
#  'great',
#  'dormouse',
#  'back',
#  'any',
#  'oh',
#  'been',
#  'before',
#  'from',
#  'cat',
#  'nothing',
#  'ive',
#  'can',
#  'last',
#  'large',
#  'march',
#  'ill',
#  'thats',
#  'tell',
#  'right',
#  'found',
#  'long',
#  'once',
#  'looking',
#  'put',
#  'will',
#  'hare',
#  'white',
#  'heard',
#  'made',
#  'next',
#  'day',
#  'dear',
#  'we',
#  'replied',
#  'door',
#  'look',
#  'moment',
#  'things',
#  'three',
#  'might',
#  'cant',
#  'eyes',
#  'should',
#  'caterpillar',
#  'good',
#  'going',
#  'seemed',
#  'poor',
#  'make',
#  'upon',
#  'too',
#  'course',
#  'rather',
#  'soon',
#  'shall',
#  'away',
#  'without',
#  'theres',
#  'while',
#  'wont',
#  'than',
#  'same',
#  'sure',
#  'took',
#  'youre',
#  'added',
#  'half',
#  'felt',
#  'jury',
#  'getting',
#  'ever',
#  'yet',
#  'another',
#  'minute',
#  'till',
#  'hand',
#  'wish',
#  'find',
#  'take',
#  'words',
#  'however',
#  'cried',
#  'sort',
#  'being',
#  'anything',
#  'please',
#  'curious',
#  'feet',
#  'tried',
#  'old',
#  'court',
#  'use',
#  'tea',
#  'house',
#  'even',
#  'table',
#  'wonder',
#  'eat',
#  'soup',
#  'something',
#  'let',
#  'perhaps',
#  'sat',
#  'enough',
#  'end',
#  'talking',
#  'side',
#  'question',
#  'asked',
#  'high',
#  'bit',
#  'indeed',
#  'hastily',
#  'turned',
#  'under',
#  'doesnt',
#  'spoke',
#  'ran',
#  'low',
#  'knew',
#  'am',
#  'idea',
#  'cats',
#  'done',
#  'garden',
#  'saying',
#  'arm',
#  'gave',
#  'because',
#  'called',
#  'air',
#  'near',
#  'saw',
#  'beautiful',
#  'anxiously',
#  'left',
#  'face',
#  'mad',
#  'certainly',
#  'set',
#  'itself',
#  'speak',
#  'didnt',
#  'us',
#  'better',
#  'hear',
#  'silence',
#  'ought',
#  'talk',
#  'suppose',
#  'sea',
#  'these',
#  'change',
#  'trying',
#  'both',
#  'seen',
#  'remember',
#  'through',
#  'whole',
#  'theyre',
#  'still',
#  'wouldnt',
#  'close',
#  'dance',
#  'people',
#  'yes',
#  'suddenly',
#  'grow',
#  'kept',
#  'footman',
#  'really',
#  'beginning',
#  'baby',
#  'size',
#  'cook',
#  'begin',
#  'where',
#  'may',
#  'room',
#  'gone',
#  'far',
#  'dodo',
#  'behind',
#  'always',
#  'give',
#  'deal',
#  'queer',
#  'turning',
#  'pigeon',
#  'finished',
#  'hardly',
#  'game',
#  'among',
#  'life',
#  'many',
#  'every',
#  'bill',
#  'best',
#  'hands',
#  'used',
#  'try',
#  'afraid',
#  'chapter',
#  'majesty',
#  'id',
#  'alices',
#  'waited',
#  'minutes',
#  'heads',
#  'nearly',
#  'tears',
#  'whether',
#  'child',
#  'mind',
#  'book',
#  'dinah',
#  'glad',
#  'makes',
#  'ask',
#  'pig',
#  'growing',
#  'turn',
#  'keep',
#  'hurry',
#  'wasnt',
#  'though',
#  'thinking',
#  'read',
#  'hurried',
#  'walked',
#  'else',
#  'sight',
#  'foot',
#  'offended',
#  'own',
#  'soldiers',
#  'lessons',
#  'either',
#  'party',
#  'box',
#  'creatures',
#  'youd',
#  'pool',
#  'repeated',
#  'word',
#  'gloves',
#  'everything',
#  'small',
#  'bottle',
#  'remarked',
#  'mouth',
#  'opened',
#  'those',
#  'rest',
#  'witness',
#  'remark',
#  'yourself',
#  'fan',
#  'mean',
#  'explain',
#  'children',
#  'name',
#  'sitting',
#  'having',
#  'glass',
#  'waiting',
#  'serpent',
#  'call',
#  'few',
#  'want',
#  'reason',
#  'rate',
#  'help',
#  'join',
#  'shouted',
#  'hall',
#  'conversation',
#  'mine',
#  'coming',
#  'does',
#  'couldnt',
#  'tail',
#  'interrupted',
#  'continued',
#  'answer',
#  'matter',
#  'shook',
#  'believe',
#  'leave',
#  'knave',
#  'key',
#  'together',
#  'butter',
#  'different',
#  'tree',
#  'croquet',
#  'hold',
#  'timidly',
#  'against',
#  'puzzled',
#  'angrily',
#  'birds',
#  'least',
#  'asleep',
#  'ready',
#  'havent',
#  'slowly',
#  'opportunity',
#  'most',
#  'hadnt',
#  'changed',
#  'mushroom',
#  'each',
#  'moral',
#  'place',
#  'hard',
#  'top',
#  'seem',
#  'story',
#  'appeared',
#  'itll',
#  'pepper',
#  'nobody',
#  'gardeners',
#  'fact',
#  'meaning',
#  'running',
#  'beg',
#  'queens',
#  'bright',
#  'everybody',
#  'sister',
#  'watch',
#  'feel',
#  'exactly',
#  'twinkle',
#  'followed',
#  'noticed',
#  'window',
#  'play',
#  'four',
#  'nose',
#  'happen',
#  'our',
#  'five',
#  'whiting',
#  'live',
#  'work',
#  'eagerly',
#  'hearts',
#  'sit',
#  'dry',
#  'lying',
#  'making',
#  'world',
#  'middle',
#  'learn',
#  'manage',
#  'frightened',
#  'fetch',
#  'treacle',
#  'trial',
#  'has',
#  'others',
#  'begun',
#  'dream',
#  'lory',
#  'wondering',
#  'chin',
#  'stood',
#  'hedgehog',
#  'grown',
#  'bread',
#  'history',
#  'william',
#  'business',
#  'repeat',
#  'cheshire',
#  'myself',
#  'isnt',
#  'deep',
#  'eye',
#  'somebody',
#  'evidence',
#  'draw',
#  'feeling',
#  'song',
#  'surprised',
#  'open',
#  'sir',
#  'lobster',
#  'goes',
#  'shoes',
#  'fish',
#  'kind',
#  'golden',
#  'fall',
#  'lobsters',
#  'distance',
#  'larger',
#  'nonsense',
#  'ground',
#  'hair',
#  'listen',
#  'tired',
#  'hot',
#  'happened',
#  'silent',
#  'generally',
#  'shes',
#  'soooop',
#  'wood',
#  'pleased',
#  'tarts',
#  'pocket',
#  'neck',
#  'drink',
#  'slates',
#  'trees',
#  'written',
#  'subject',
#  'youve',
#  'executed',
#  'broken',
#  'trembling',
#  'exclaimed',
#  'late',
#  'chimney',
#  'melancholy',
#  'politely',
#  'shant',
#  'sleep',
#  'english',
#  'sing',
#  'inches',
#  'jumped',
#  'leaves',
#  'wow',
#  'race',
#  'ear',
#  'forgotten',
#  'youll',
#  'ten',
#  'almost',
#  'youth',
#  'full',
#  'sharp',
#  'roof',
#  'stop',
#  'marked',
#  'chorus',
#  'trouble',
#  'loud',
#  'school',
#  'puppy',
#  'writing',
#  'fell',
#  'times',
#  'seven',
#  'nice',
#  'grin',
#  'pigs',
#  'stupid',
#  'guinea',
#  'piece',
#  'between',
#  'told',
#  'stand',
#  'write',
#  'pardon',
#  'arms',
#  'sentence',
#  'father',
#  'dreadfully',
#  'understand',
#  'himself',
#  'liked',
#  'sneezing',
#  'along',
#  'rose',
#  'altogether',
#  'dare',
#  'whats',
#  'shut',
#  'notice',
#  'finger',
#  'faces',
#  'twice',
#  'nervous',
#  'cut',
#  'prizes',
#  'simple',
#  'fancy',
#  'sleepy',
#  'walking',
#  'speaking',
#  'dropped',
#  'swam',
#  'number',
#  'case',
#  'usual',
#  'morning',
#  'executioner',
#  'water',
#  'ah',
#  'tis',
#  'sudden',
#  'stay',
#  'sadly',
#  'seems',
#  'lets',
#  'strange',
#  'sounded',
#  'nearer',
#  'ears',
#  'important',
#  'kid',
#  'procession',
#  'rule',
#  'pack',
#  'remembered',
#  'crowded',
#  'knee',
#  'adventures',
#  'happens',
#  'whispered',
#  'wrong',
#  'pair',
#  'flamingo',
#  'nine',
#  'angry',
#  'shrill',
#  'until',
#  'animals',
#  'confusion',
#  'sometimes',
#  'become',
#  'home',
#  'across',
#  'sky',
#  'reply',
#  'waving',
#  'eggs',
#  'impatiently',
#  'instantly',
#  'surprise',
#  'sighed',
#  'direction',
#  'asking',
#  'temper',
#  'lizard',
#  'likely',
#  'doing',
#  'young',
#  'aloud',
#  'night',
#  'often',
#  'swim',
#  'moved',
#  'height',
#  'quietly',
#  'hookah',
#  'man',
#  'meant',
#  'finish',
#  'interesting',
#  'drew',
#  'curiosity',
#  'shriek',
#  'new',
#  'passed',
#  'walk',
#  'shouldnt',
#  'taking',
#  'rabbits',
#  'plan',
#  'players',
#  'outside',
#  'difficulty',
#  'puzzling',
#  'besides',
#  'except',
#  'twelve',
#  'mabel',
#  'tiny',
#  'age',
#  'stick',
#  'grass',
#  'shoulder',
#  'ordered',
#  'french',
#  'crumbs',
#  'fast',
#  'held',
#  'shrinking',
#  'alone',
#  'fellow',
#  'thank',
#  'master',
#  'worth',
#  'dead',
#  'escape',
#  'turtles',
#  'bills',
#  'hearing',
#  'doubt',
#  'sounds',
#  'honour',
#  'yer',
#  'digging',
#  'lay',
#  'crowd',
#  'sound',
#  'violently',
#  'capital',
#  'savage',
#  'quadrille',
#  'sharply',
#  'beauootiful',
#  'trials',
#  'hours',
#  'reach',
#  'theyll',
#  'jurors',
#  'lives',
#  'otherwise',
#  'led',
#  'ventured',
#  'deeply',
#  'carried',
#  'taught',
#  'dish',
#  'managed',
#  'days',
#  'kitchen',
#  'paper',
#  'jumping',
#  'officers',
#  'fear',
#  'suppressed',
#  'jurymen',
#  'verses',
#  'hole',
#  'shoulders',
#  'severely',
#  'busily',
#  'sides',
#  'fallen',
#  'perfectly',
#  'none',
#  'several',
#  'sobs',
#  'chance',
#  'questions',
#  'stuff',
#  'decidedly',
#  'earth',
#  'alas',
#  'boots',
#  'grunted',
#  'creature',
#  'taken',
#  'thoughtfully',
#  'true',
#  'porpoise',
#  'pictures',
#  'green',
#  'verse',
#  'care',
#  'screamed',
#  'indignantly',
#  'person',
#  'beat',
#  'second',
#  'less',
#  'answered',
#  'girl',
#  'sigh',
#  'twinkling',
#  'dogs',
#  'theyd',
#  'passage',
#  'solemnly',
#  'says',
#  'confused',
#  'pointing',
#  'pale',
#  'argument',
#  'uncomfortable',
#  'consider',
#  'shore',
#  'run',
#  'duck',
#  'begins',
#  'since',
#  'tale',
#  'judge',
#  'breath',
#  'vanished',
#  'ann',
#  'natural',
#  'bats',
#  'mary',
#  'paws',
#  'frowning',
#  'bottom',
#  'bowed',
#  'miss',
#  'fire',
#  'means',
#  'wanted',
#  'tongue',
#  'short',
#  'thimble',
#  'arches',
#  'bring',
#  'pleaded',
#  'panther',
#  'shaped',
#  'easily',
#  'bat',
#  'joined',
#  'girls',
#  'catch',
#  'dull',
#  'attending',
#  'miles',
#  'tasted',
#  'caught',
#  'mark',
#  'toes',
#  'pie',
#  'pressed',
#  'dears',
#  'peeped',
#  'checked',
#  'opening',
#  'fond',
#  'serpents',
#  'yours',
#  'watching',
#  'tails',
#  'remained',
#  'beheaded',
#  'shaking',
#  'holding',
#  'mouths',
#  'free',
#  'crown',
#  'crab',
#  'obliged',
#  'smaller',
#  'succeeded',
#  'tossing',
#  'reading',
#  'dark',
#  'cake',
#  'roses',
#  'move',
#  'follows',
#  'snail',
#  'pity',
#  'around',
#  'frog',
#  'owl',
#  'expecting',
#  'oclock',
#  'trumpet',
#  'upset',
#  'speech',
#  'past',
#  'handed',
#  'teacup',
#  'red',
#  'fury',
#  'howling',
#  'wrote',
#  'sighing',
#  'instance',
#  'gravely',
#  'repeating',
#  'poison',
#  'hes',
#  'nursing',
#  'cheered',
#  'settled',
#  'list',
#  'rules',
#  'grave',
#  'hoping',
#  'sad',
#  'lived',
#  'impossible',
#  'unimportant',
#  'grinned',
#  'courage',
#  'solemn',
#  'fit',
#  'telescope',
#  'noise',
#  'growl',
#  'verdict',
#  'staring',
#  'met',
#  'eeevening',
#  'legs',
#  'hope',
#  'possibly',
#  'decided',
#  'proper',
#  'mice',
#  'pieces',
#  'candle',
#  'nibbling',
#  'bringing',
#  'further',
#  'filled',
#  'lady',
#  'delight',
#  'advantage',
#  'livery',
#  'spectacles',
#  'considered',
#  'slate',
#  'loudly',
#  'letter',
#  'finding',
#  'stairs',
#  'later',
#  'certain',
#  'faster',
#  'order',
#  'knife',
#  'particular',
#  'sobbing',
#  'figure',
#  'passion',
#  'shell',
#  'real',
#  'guess',
#  'kick',
#  'hurt',
#  'unfortunate',
#  'above',
#  'knocking',
#  'putting',
#  'fun',
#  'plate',
#  'mistake',
#  'mustard',
#  'gently',
#  'throw',
#  'sense',
#  'spread',
#  'moving',
#  'funny',
#  'civil',
#  'themselves',
#  'hoarse',
#  'cakes',
#  'crossed',
#  'doth',
#  'neednt',
#  'eaglet',
#  'whisper',
#  'cause',
#  'below',
#  'twenty',
#  'turns',
#  'tucked',
#  'show',
#  'whatever',
#  'cautiously',
#  'lesson',
#  'whiskers',
#  'nor',
#  'notion',
#  'longer',
#  'stopped',
#  'lost',
#  'forgetting',
#  'elbow',
#  'effect',
#  'hush',
#  ...]

# %%
"""
    Q) What is the 10th word in our vocabulary?
"""

model.wv.index_to_key[10]
# Out:
# 'was'

# %% [markdown]
# ### 2-3. Word embedding vectors

# %%
model.wv  # it's a special datatype exclusively used by the gensim library

# %%
"""
    Q) What the word vector for 'alice'?
        - Treat 'model.wv' as a python dictionary.
        - Use the string 'alice' as the key, and it will return the
          the word embedding vector that the model has learned.
"""

model.wv['was']  # was의 embedding vector. 차원은 지정했던대로 100차원.
# Out:
# array([-0.7648241 , -2.171586  ,  0.81657743, -0.28726956, -0.2485494 ,
#         0.19138649, -1.0530378 , -1.0284163 , -2.361386  , -0.4315796 ,
#         0.34746924,  0.7861353 , -0.3775395 , -2.0935822 ,  1.0322199 ,
#         0.89117694,  0.5005209 ,  0.23650514, -1.0501304 ,  1.9605324 ,
#         2.3270943 , -1.2471851 ,  2.1703086 ,  0.73370785,  2.02952   ,
#         0.47547966,  0.72619236,  0.4540573 ,  1.3711619 ,  1.5690695 ,
#         0.27779254,  0.85145515,  0.17296651, -1.150265  ,  0.59570485,
#        -0.57433444, -0.18433835,  0.43712854,  2.3970835 ,  0.26640704,
#         0.12668718,  0.54101205,  0.79475313,  1.8195338 , -1.5858712 ,
#        -1.119407  ,  1.4717599 , -0.01747941, -0.92666125,  0.451088  ,
#        -1.3933736 , -1.7236149 , -2.9459114 , -2.19814   ,  0.42909905,
#        -1.247871  ,  0.5416361 , -1.330222  ,  2.2865705 , -1.4958233 ,
#        -2.2918012 ,  0.97478276,  0.27958277, -0.44752672, -0.83434486,
#        -1.3614043 , -1.0304728 ,  0.5324266 ,  1.3017192 , -3.2910645 ,
#         1.8856932 , -1.19931   ,  0.04907954,  1.8144892 ,  0.8979416 ,
#         1.9948173 ,  0.45864236, -1.5749768 ,  0.13231644, -0.19745448,
#         0.91668123,  0.17001481,  0.2757937 , -0.30762058,  1.6047174 ,
#         0.27047896, -1.1143497 , -0.85581475, -0.5671519 ,  1.632644  ,
#         0.2895568 , -0.6966454 , -0.2741443 ,  1.4024212 , -1.3075746 ,
#        -0.5465852 ,  1.0400996 , -0.74957854, -1.0382017 , -2.1932058 ],
#       dtype=float32)

# %%
model.wv['alice'].shape
# Out:
# (100,)

# %% [markdown]
# ### 2-4. Indentifying similar vectors

# %%
"""
    Q) What are the 5 most similar words to `alice`?
        - The 'most_similar' method returns a list of tuples,
          where each tuple is a (word, cosine_similarity) pair.
"""

model.wv.most_similar('alice', topn=5) # 튜플 형태(단어, 코사인 유사도 값)
# Out:
# [('she', 0.5439764857292175),
#  ('it', 0.4308808445930481),
#  ('but', 0.3920069634914398),
#  ('unhappy', 0.3268224000930786),
#  ('that', 0.2968774437904358)]

# %%
"""
    Q) What are the 10 most similar words to 'time'?
"""

model.wv.most_similar('time', topn=10)
# Out:
# [('minutes', 0.4379795491695404),
#  ('pool', 0.3897824287414551),
#  ('silence', 0.3810037076473236),
#  ('finished', 0.3289918601512909),
#  ('once', 0.30491042137145996),
#  ('moment', 0.30395081639289856),
#  ('paper', 0.3030426800251007),
#  ('back', 0.2929920554161072),
#  ('noise', 0.28808119893074036),
#  ('concert', 0.2783009111881256)]

# %%
"""
    What are the 7 most similar words to 'face'?
"""

model.wv.most_similar('face')
# Out:
# [('beating', 0.4483812749385834),
#  ('eyes', 0.4196746349334717),
#  ('folded', 0.4189411997795105),
#  ('turn', 0.3936787247657776),
#  ('violently', 0.3767057955265045),
#  ('looked', 0.3761976361274719),
#  ('paws', 0.37475699186325073),
#  ('chin', 0.35099056363105774),
#  ('afterwards', 0.346349835395813),
#  ('arms', 0.34370121359825134)]

# %% [markdown]
# ### 2-5. Loading and Saving Models

# %%
# 모델을 저장할 경로 설정, ~경로/모델 이름.model -> 확장자를 model로 줌으로써 다른 파일과 헷갈리지 않게 한다.
model.save("/content/drive/My Drive/Colab Notebooks/2024-2 딥러닝/E. Vector Representations of Text/word2vec_model.model")

# %%
loaded_model = Word2Vec.load("/content/drive/My Drive/Colab Notebooks/2024-2 딥러닝/E. Vector Representations of Text/word2vec_model.model")  # load

# %%
loaded_model.wv['was']
# Out:
# array([-0.7648241 , -2.171586  ,  0.81657743, -0.28726956, -0.2485494 ,
#         0.19138649, -1.0530378 , -1.0284163 , -2.361386  , -0.4315796 ,
#         0.34746924,  0.7861353 , -0.3775395 , -2.0935822 ,  1.0322199 ,
#         0.89117694,  0.5005209 ,  0.23650514, -1.0501304 ,  1.9605324 ,
#         2.3270943 , -1.2471851 ,  2.1703086 ,  0.73370785,  2.02952   ,
#         0.47547966,  0.72619236,  0.4540573 ,  1.3711619 ,  1.5690695 ,
#         0.27779254,  0.85145515,  0.17296651, -1.150265  ,  0.59570485,
#        -0.57433444, -0.18433835,  0.43712854,  2.3970835 ,  0.26640704,
#         0.12668718,  0.54101205,  0.79475313,  1.8195338 , -1.5858712 ,
#        -1.119407  ,  1.4717599 , -0.01747941, -0.92666125,  0.451088  ,
#        -1.3933736 , -1.7236149 , -2.9459114 , -2.19814   ,  0.42909905,
#        -1.247871  ,  0.5416361 , -1.330222  ,  2.2865705 , -1.4958233 ,
#        -2.2918012 ,  0.97478276,  0.27958277, -0.44752672, -0.83434486,
#        -1.3614043 , -1.0304728 ,  0.5324266 ,  1.3017192 , -3.2910645 ,
#         1.8856932 , -1.19931   ,  0.04907954,  1.8144892 ,  0.8979416 ,
#         1.9948173 ,  0.45864236, -1.5749768 ,  0.13231644, -0.19745448,
#         0.91668123,  0.17001481,  0.2757937 , -0.30762058,  1.6047174 ,
#         0.27047896, -1.1143497 , -0.85581475, -0.5671519 ,  1.632644  ,
#         0.2895568 , -0.6966454 , -0.2741443 ,  1.4024212 , -1.3075746 ,
#        -0.5465852 ,  1.0400996 , -0.74957854, -1.0382017 , -2.1932058 ],
#       dtype=float32)

# %%
loaded_model.wv.key_to_index['was']
# Out:
# 10

# %%
loaded_model.wv[10]
# Out:
# array([-0.7648241 , -2.171586  ,  0.81657743, -0.28726956, -0.2485494 ,
#         0.19138649, -1.0530378 , -1.0284163 , -2.361386  , -0.4315796 ,
#         0.34746924,  0.7861353 , -0.3775395 , -2.0935822 ,  1.0322199 ,
#         0.89117694,  0.5005209 ,  0.23650514, -1.0501304 ,  1.9605324 ,
#         2.3270943 , -1.2471851 ,  2.1703086 ,  0.73370785,  2.02952   ,
#         0.47547966,  0.72619236,  0.4540573 ,  1.3711619 ,  1.5690695 ,
#         0.27779254,  0.85145515,  0.17296651, -1.150265  ,  0.59570485,
#        -0.57433444, -0.18433835,  0.43712854,  2.3970835 ,  0.26640704,
#         0.12668718,  0.54101205,  0.79475313,  1.8195338 , -1.5858712 ,
#        -1.119407  ,  1.4717599 , -0.01747941, -0.92666125,  0.451088  ,
#        -1.3933736 , -1.7236149 , -2.9459114 , -2.19814   ,  0.42909905,
#        -1.247871  ,  0.5416361 , -1.330222  ,  2.2865705 , -1.4958233 ,
#        -2.2918012 ,  0.97478276,  0.27958277, -0.44752672, -0.83434486,
#        -1.3614043 , -1.0304728 ,  0.5324266 ,  1.3017192 , -3.2910645 ,
#         1.8856932 , -1.19931   ,  0.04907954,  1.8144892 ,  0.8979416 ,
#         1.9948173 ,  0.45864236, -1.5749768 ,  0.13231644, -0.19745448,
#         0.91668123,  0.17001481,  0.2757937 , -0.30762058,  1.6047174 ,
#         0.27047896, -1.1143497 , -0.85581475, -0.5671519 ,  1.632644  ,
#         0.2895568 , -0.6966454 , -0.2741443 ,  1.4024212 , -1.3075746 ,
#        -0.5465852 ,  1.0400996 , -0.74957854, -1.0382017 , -2.1932058 ],
#       dtype=float32)

# %% [markdown]
# # wv와 wv.vectors 차이
# wv는 검색과 메타정보를 포함한 고수준 관리 객체, wv.vectors는 단순히 벡터를 저장하는 배열

# %%
loaded_model.wv.vectors[10]
# Out:
# array([-0.7648241 , -2.171586  ,  0.81657743, -0.28726956, -0.2485494 ,
#         0.19138649, -1.0530378 , -1.0284163 , -2.361386  , -0.4315796 ,
#         0.34746924,  0.7861353 , -0.3775395 , -2.0935822 ,  1.0322199 ,
#         0.89117694,  0.5005209 ,  0.23650514, -1.0501304 ,  1.9605324 ,
#         2.3270943 , -1.2471851 ,  2.1703086 ,  0.73370785,  2.02952   ,
#         0.47547966,  0.72619236,  0.4540573 ,  1.3711619 ,  1.5690695 ,
#         0.27779254,  0.85145515,  0.17296651, -1.150265  ,  0.59570485,
#        -0.57433444, -0.18433835,  0.43712854,  2.3970835 ,  0.26640704,
#         0.12668718,  0.54101205,  0.79475313,  1.8195338 , -1.5858712 ,
#        -1.119407  ,  1.4717599 , -0.01747941, -0.92666125,  0.451088  ,
#        -1.3933736 , -1.7236149 , -2.9459114 , -2.19814   ,  0.42909905,
#        -1.247871  ,  0.5416361 , -1.330222  ,  2.2865705 , -1.4958233 ,
#        -2.2918012 ,  0.97478276,  0.27958277, -0.44752672, -0.83434486,
#        -1.3614043 , -1.0304728 ,  0.5324266 ,  1.3017192 , -3.2910645 ,
#         1.8856932 , -1.19931   ,  0.04907954,  1.8144892 ,  0.8979416 ,
#         1.9948173 ,  0.45864236, -1.5749768 ,  0.13231644, -0.19745448,
#         0.91668123,  0.17001481,  0.2757937 , -0.30762058,  1.6047174 ,
#         0.27047896, -1.1143497 , -0.85581475, -0.5671519 ,  1.632644  ,
#         0.2895568 , -0.6966454 , -0.2741443 ,  1.4024212 , -1.3075746 ,
#        -0.5465852 ,  1.0400996 , -0.74957854, -1.0382017 , -2.1932058 ],
#       dtype=float32)
